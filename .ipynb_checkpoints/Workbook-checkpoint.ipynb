# %%
import stanza
from nltk import tokenize
from torch.cuda import empty_cache

# %%
class Coref:
    def __init__(self, coref):
        self.coref = coref
        self.props = {}
    
    def add_props(self, prop_name, prop_val):
        self.props[prop_name] = prop_val

# %%
class Node:
    def __init__(self, word, article):
        self.word = word
        self.article = article
        self.corefs = []
        
    def add_coref(self, coref):
        if coref not in self.corefs:
            self.corefs.append(coref)

# %%
pipe = stanza.Pipeline("en", processors="tokenize,coref,mwt,pos", pos_batch_size=100)
# Out:
# 2024-05-26 17:07:14 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.8.0.json:   0%|   …
# 2024-05-26 17:07:15 INFO: Downloaded file to C:\Users\ivano\stanza_resources\resources.json
# 2024-05-26 17:07:15 INFO: Loading these models for language: en (English):
# =======================================
# | Processor | Package                 |
# ---------------------------------------
# | tokenize  | combined                |
# | mwt       | combined                |
# | pos       | combined_charlm         |
# | coref     | ontonotes_electra-large |
# =======================================
#
# 2024-05-26 17:07:15 INFO: Using device: cuda
# 2024-05-26 17:07:15 INFO: Loading: tokenize
# 2024-05-26 17:07:16 INFO: Loading: mwt
# 2024-05-26 17:07:16 INFO: Loading: pos
# 2024-05-26 17:07:17 INFO: Loading: coref
# C:\Users\ivano\anaconda3\envs\torch1\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# C:\Users\ivano\anaconda3\envs\torch1\lib\site-packages\torch\_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# 2024-05-26 17:07:27 INFO: Done loading processors!

# %%
text = 'The tendency towards colossal quantities of research may force science both ways – both accelerating and trampling its progress. In the context of this paper a concept is defined as an entity and its description(s). '

# %%
text = '''
Chaotic systems, both social and natural, have a widespread currency. This may explain a constantly increasing number of prediction algorithms for chaotic time series. It is worth stressing however, that while the algorithms for a single-step-ahead prediction (Aghabozorgi et al., 2015) appear to be amazingly efficient; their counterparts for a multi-step ahead (MSA) prediction are still in their infancy. One may attribute this fact to an exponential growth of an average prediction error with a prediction horizon, that is the number of steps ahead to be predicted. 
This exponential growth reflects Lyapunov instability, immanent to any chaotic system. Namely, according to Lyapunov instability definition, however small is any initial difference between two neighbouring trajectories, the difference grows exponentially with time, and its exponent equals to the highest Lyapunov exponent (Kantz & Schreiber, 2003; Malinetskii & Potapov, 2000). Laypunov instability also leads to another concept, that of a horizon of predictability (sometimes also referred to as Lyapunov time (Bezruchko & Smirnov, 2010)). For a given observational error  and the maximum prediction error , the exponential growth mentioned above satisfies, thereby giving a horizon of predictability  (Kantz & Schreiber, 2003; Malinetskii & Potapov, 2000). In the context of a multi-step ahead prediction, this implies that the smallest difference between true and predicted values in an intermediate point (that is the point between the last observable point and the point to be predicted) – inevitable for any prediction method – triggers exponential error growth in all subsequent intermediate points and in the point to be predicted itself. Therefore, a horizon of predictability is an upper theoretical boundary for the number of steps ahead to be predicted for any prediction algorithm (for given  and ). A horizon of predictability should not be confused with a prediction horizon, which is a mere number of steps ahead the algorithm makes its prediction. Usually, a prediction horizon  is essentially lesser than a horizon of predictability : .
Nonetheless, this apparently inevitable exponential growth only seems to be so. Predictive clustering (Blockeel & De Raedt, 1998; Gromov & Borisenko, 2015) furnishes several tools that, applied together, make it possible to avoid it.
First, predictive clustering uses motifs – repeated sequences of data in a series (with some small variations). If a section of a time series resembles first part of a motif ‘closely enough’, it is likely that the subsequent points of a series will be close to the subsequent points of the motif, allowing one to use motifs to predict next points of the time series. Motifs can be obtained by clustering vectors of non-successive observations of a series into z-vectors (irregular embeddings (Small, 2005)) and calculating their respective centers. It is worth stressing that most available prediction methods attempt to construct a unified, global prediction model, whereas predictive clustering methods, vice versa, build up a set of separate, local prediction models, motifs (cf. global vs. local learning (Ben Taieb et al., 2010; Gromov, 2019)).
Second, predictive clustering allows one to develop the concept of non-predictable points in a natural way (Gromov & Borisenko, 2015). Initially, an unpredictable point was the fone for which the algorithm failed to find a corresponding motif that would be close enough and based on which the possible value of the point could be estimated (a set of possible predicted values is empty for it. It is worthy to emphasize that if one introduces the concept of non-predictable points (non-predictables), one thereby renders the problem two-objective: one must minimise simultaneously the number of non-predictable points and the average error over predictable ones. In the conventional statement, the first objective is discarded – predictions are made for every single point. Introduction of unpredictable points proved to have a positive effect on the results – it is better for algorithm to skip some points along the way for which it is unable to find a proper predicted value rather than forcing it regardless of whether this predicted value will be accurate or not. This approach is actually quite natural in some areas: for example, traders are not compelled to buy and/or sell at every single moment – instead, they may choose only those moments in time that the algorithm has recognized as predictable.
In the context of dynamical systems (Kantz & Schreiber, 2003; Malinetskii & Potapov, 2000), each cluster of z-vectors (by definition, it includes similar sections of a trajectory) corresponds to a particular area of a strange attractor. Furthermore, areas with high values of an invariant measure are associated with large clusters (i.e., with frequently observed motifs). Similarly, areas with smaller values of the invariant measure are associated with smaller clusters (i.e., rarely observed motifs). Consequently, as a training set increases – so does the number of clusters, while the number of unpredictable points, as well as the average error of the predictable ones, decrease. A large-scale simulation for the Lorenz series (Gromov, 2019) supports this conclusion.
Third, Gromov and Borisenko (2015) use generalized z-vectors – vectors comprised of non-successive observations according to certain predefined patterns (irregular embeddings (Small, 2005)). A pattern is defined as a sequence of distances between positions of observations in a series, such that these (non-successive) observations become successive in a generated vector. This concatenated vector generalizes a conventional z-vector (Kantz & Schreiber, 2003; Malinetskii & Potapov, 2000), which corresponds to the pattern  ( times). Figure 1 presents a sample vector constructed according to the pattern   and shows the way z-vectors are clustered into motifs and how the motifs can be used to obtain predictions for the time series at hand. The process of generating a z-vector can be visualized as placing a ‘comb’ with  teeth where tooth  is ‘broken’ and the distances between the remaining  teeth correspond to some pattern. Moving the comb along the series, we, for each position , obtain a vector of observations, to be under the teeth of the comb, . To put it differently, for a given pattern, a conventional sliding window is replaced by a sliding comb with the majority of its teeth broken off. A set of such vectors comprises a sample corresponding to a pattern of    . Each such sample is clustered separately. 
Fourth, due to the fact that the number of patterns can be significant, so can the number of possible predicted values at each point; however, they are not always statistically independent. This makes it possible to design a great deal of various algorithms to determine a unified prediction value for a set of possible prediction values (for instance, by averaging them). It also becomes possible to extend the concept of the unpredictable points: apart from the points that do not have a corresponding motif that would be close enough, we can also consider points for which it is impossible to calculate a unified prediction value based on the set of possible predicted values to be unpredictable as well. An example case of such a point would be a point which set of predicted values consists of two equally sized clusters with different centres. It is worth stressing that in our previous paper (Gromov & Borisenko, 2015) we employed non-predictable points of the first kind only (a point is non-predictable if there are no motifs close enough to make predictions for it). In the present paper, we employ both kinds of non-predictable points – and this appears to make it possible for the proposed algorithm to predict for so many steps ahead.   
It is worth noting that since patterns with a distance between penultimate and ultimate teeth greater than 1, , exist, the fact that a position  is non-predictable does not imply that positions , , etc. would be non-predictable too. This fact is of fundamental importance for multi-step ahead prediction: If one needs to predict a point at a position , one would use the iterative strategy (or rather its modification based on patterns of non-successive observations). Namely, one predicts values for intermediate positions between  and  step by step, identifying unpredictable points along the way and stepping over them. This results in unpredictable sections between predictable positions. We used to refer to the former as a ‘bog’, and to the latter as ‘hillocks’. The entire prediction process is likened to jumping from a hillock to hillock in order to navigate a swamp (or to put it differently – using stepping stones).
While the algorithm cannot produce a prediction at each point (thus the word ‘partial’ in the title), it can predict values up to the horizon of predictability and sometimes even further. While the algorithm cannot produce a prediction at each point (thus the word ‘partial’ in the title), it can predict values up to the horizon of predictability and sometimes even further. This paper presents several methods of identifying unpredictable points and corresponding strategies for the multi-step ahead prediction as well as demonstrates partial predictions beyond the horizon of predictability for the benchmark and real-world time series.
The rest of the paper is organized as follows. The next section reviews recent advances in the field; the third section formally states the problems under study; the fourth outlines clustering method, and methods employed to obtain predictions and also identify non-predictable points; the fifth section provides the prediction results for a time series generated by the Lorenz system, and a time series of hourly load values in Germany. Finally, the last section presents conclusions.

'''

# %%
text = article

# %%
import os

os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "max_split_size_mb:500"

# %%
from torch.cuda import empty_cache
import gc
gc.collect()
empty_cache()

# %%
# Out:
# 560

# %%
# %%time
result = pipe(text[:len(text)//100])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File <timed exec>:1
#
# File ~\anaconda3\envs\torch1\lib\site-packages\stanza\pipeline\core.py:480, in Pipeline.__call__(self, doc, processors)
#     479 def __call__(self, doc, processors=None):
# --> 480     return self.process(doc, processors)
#
# File ~\anaconda3\envs\torch1\lib\site-packages\stanza\pipeline\core.py:431, in Pipeline.process(self, doc, processors)
#     429     if self.processors.get(processor_name):
#     430         process = self.processors[processor_name].bulk_process if bulk else self.processors[processor_name].process
# --> 431         doc = process(doc)
#     432 return doc
#
# File ~\anaconda3\envs\torch1\lib\site-packages\stanza\pipeline\coref_processor.py:100, in CorefProcessor.process(self, document)
#      94 coref_input = {
#      95     "document_id": "wb_doc_1",
#      96     "cased_words": cased_words,
#      97     "sent_id": sent_ids
#      98 }
#      99 coref_input = self._model.build_doc(coref_input)
# --> 100 results = self._model.run(coref_input)
#     101 clusters = []
#     102 for span_cluster in results.span_clusters:
#
# File ~\anaconda3\envs\torch1\lib\site-packages\stanza\models\coref\model.py:350, in CorefModel.run(self, doc)
#     346 res.coref_scores = torch.cat(a_scores_lst, dim=0)
#     348 res.coref_y = self._get_ground_truth(
#     349     cluster_ids, top_indices, (top_rough_scores > float("-inf")))
# --> 350 res.word_clusters = self._clusterize(doc, res.coref_scores,
#     351                                      top_indices)
#     352 res.span_scores, res.span_y = self.sp.get_training_data(doc, words)
#     354 if not self.training:
#
# File ~\anaconda3\envs\torch1\lib\site-packages\stanza\models\coref\model.py:587, in CorefModel._clusterize(self, doc, scores, top_indices)
#     585 for i, j in zip(coref_span_heads.tolist(), antecedents.tolist()):
#     586     nodes[i].link(nodes[j])
# --> 587     assert nodes[i] is not nodes[j]
#     589 clusters = []
#     590 for node in nodes:
#
# AssertionError:

# %%
dicts = result.to_dict()

# %%
dicts
# Out:
# [[{'id': 1,
#    'text': 'Chaotic',
#    'start_char': 1,
#    'end_char': 8,
#    'coref_chains': [],
#    'misc': 'SpacesBefore=\\n'},
#   {'id': 2,
#    'text': 'systems',
#    'start_char': 9,
#    'end_char': 16,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 3, 'text': ',', 'start_char': 16, 'end_char': 17, 'coref_chains': []},
#   {'id': 4,
#    'text': 'both',
#    'start_char': 18,
#    'end_char': 22,
#    'coref_chains': []},
#   {'id': 5,
#    'text': 'social',
#    'start_char': 23,
#    'end_char': 29,
#    'coref_chains': []},
#   {'id': 6,
#    'text': 'and',
#    'start_char': 30,
#    'end_char': 33,
#    'coref_chains': []},
#   {'id': 7,
#    'text': 'natural',
#    'start_char': 34,
#    'end_char': 41,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 8, 'text': ',', 'start_char': 41, 'end_char': 42, 'coref_chains': []},
#   {'id': 9,
#    'text': 'have',
#    'start_char': 43,
#    'end_char': 47,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3ed4ea30>]},
#   {'id': 10,
#    'text': 'a',
#    'start_char': 48,
#    'end_char': 49,
#    'coref_chains': []},
#   {'id': 11,
#    'text': 'widespread',
#    'start_char': 50,
#    'end_char': 60,
#    'coref_chains': []},
#   {'id': 12,
#    'text': 'currency',
#    'start_char': 61,
#    'end_char': 69,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 13,
#    'text': '.',
#    'start_char': 69,
#    'end_char': 70,
#    'coref_chains': []}],
#  [{'id': 1,
#    'text': 'This',
#    'start_char': 71,
#    'end_char': 75,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3ed4ea90>]},
#   {'id': 2,
#    'text': 'may',
#    'start_char': 76,
#    'end_char': 79,
#    'coref_chains': []},
#   {'id': 3,
#    'text': 'explain',
#    'start_char': 80,
#    'end_char': 87,
#    'coref_chains': []},
#   {'id': 4, 'text': 'a', 'start_char': 88, 'end_char': 89, 'coref_chains': []},
#   {'id': 5,
#    'text': 'constantly',
#    'start_char': 90,
#    'end_char': 100,
#    'coref_chains': []},
#   {'id': 6,
#    'text': 'increasing',
#    'start_char': 101,
#    'end_char': 111,
#    'coref_chains': []},
#   {'id': 7,
#    'text': 'number',
#    'start_char': 112,
#    'end_char': 118,
#    'coref_chains': []},
#   {'id': 8,
#    'text': 'of',
#    'start_char': 119,
#    'end_char': 121,
#    'coref_chains': []},
#   {'id': 9,
#    'text': 'prediction',
#    'start_char': 122,
#    'end_char': 132,
#    'coref_chains': []},
#   {'id': 10,
#    'text': 'algorithms',
#    'start_char': 133,
#    'end_char': 143,
#    'coref_chains': []},
#   {'id': 11,
#    'text': 'for',
#    'start_char': 144,
#    'end_char': 147,
#    'coref_chains': []},
#   {'id': 12,
#    'text': 'chaotic',
#    'start_char': 148,
#    'end_char': 155,
#    'coref_chains': []},
#   {'id': 13,
#    'text': 'time',
#    'start_char': 156,
#    'end_char': 160,
#    'coref_chains': []},
#   {'id': 14,
#    'text': 'series',
#    'start_char': 161,
#    'end_char': 167,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 15,
#    'text': '.',
#    'start_char': 167,
#    'end_char': 168,
#    'coref_chains': []}],
#  [{'id': 1,
#    'text': 'It',
#    'start_char': 169,
#    'end_char': 171,
#    'coref_chains': []},
#   {'id': 2,
#    'text': 'is',
#    'start_char': 172,
#    'end_char': 174,
#    'coref_chains': []},
#   {'id': 3,
#    'text': 'worth',
#    'start_char': 175,
#    'end_char': 180,
#    'coref_chains': []},
#   {'id': 4,
#    'text': 'stressing',
#    'start_char': 181,
#    'end_char': 190,
#    'coref_chains': []},
#   {'id': 5,
#    'text': 'however',
#    'start_char': 191,
#    'end_char': 198,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 6,
#    'text': ',',
#    'start_char': 198,
#    'end_char': 199,
#    'coref_chains': []},
#   {'id': 7,
#    'text': 'that',
#    'start_char': 200,
#    'end_char': 204,
#    'coref_chains': []},
#   {'id': 8,
#    'text': 'while',
#    'start_char': 205,
#    'end_char': 210,
#    'coref_chains': []},
#   {'id': 9,
#    'text': 'the',
#    'start_char': 211,
#    'end_char': 214,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3ed4eaf0>]},
#   {'id': 10,
#    'text': 'algorithms',
#    'start_char': 215,
#    'end_char': 225,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3ed4eb50>]},
#   {'id': 11,
#    'text': 'for',
#    'start_char': 226,
#    'end_char': 229,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3ed4ebb0>]},
#   {'id': 12,
#    'text': 'a',
#    'start_char': 230,
#    'end_char': 231,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3ed4ec10>]},
#   {'id': 13,
#    'text': 'single',
#    'start_char': 232,
#    'end_char': 238,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3ed4ec70>],
#    'misc': 'SpaceAfter=No'},
#   {'id': 14,
#    'text': '-',
#    'start_char': 238,
#    'end_char': 239,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3ed4ecd0>],
#    'misc': 'SpaceAfter=No'},
#   {'id': 15,
#    'text': 'step',
#    'start_char': 239,
#    'end_char': 243,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3ed4ed30>],
#    'misc': 'SpaceAfter=No'},
#   {'id': 16,
#    'text': '-',
#    'start_char': 243,
#    'end_char': 244,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3ed4ed90>],
#    'misc': 'SpaceAfter=No'},
#   {'id': 17,
#    'text': 'ahead',
#    'start_char': 244,
#    'end_char': 249,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3ed4edf0>]},
#   {'id': 18,
#    'text': 'prediction',
#    'start_char': 250,
#    'end_char': 260,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3ed4ee50>]},
#   {'id': 19,
#    'text': '(',
#    'start_char': 261,
#    'end_char': 262,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3ed4eeb0>],
#    'misc': 'SpaceAfter=No'},
#   {'id': 20,
#    'text': 'Aghabozorgi',
#    'start_char': 262,
#    'end_char': 273,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3ed4ef10>]},
#   {'id': 21,
#    'text': 'et',
#    'start_char': 274,
#    'end_char': 276,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3ed4ef70>]},
#   {'id': 22,
#    'text': 'al.',
#    'start_char': 277,
#    'end_char': 280,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3ed4efd0>],
#    'misc': 'SpaceAfter=No'},
#   {'id': 23,
#    'text': ',',
#    'start_char': 280,
#    'end_char': 281,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b1070>]},
#   {'id': 24,
#    'text': '2015',
#    'start_char': 282,
#    'end_char': 286,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b10d0>],
#    'misc': 'SpaceAfter=No'},
#   {'id': 25,
#    'text': ')',
#    'start_char': 286,
#    'end_char': 287,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b1130>]},
#   {'id': 26,
#    'text': 'appear',
#    'start_char': 288,
#    'end_char': 294,
#    'coref_chains': []},
#   {'id': 27,
#    'text': 'to',
#    'start_char': 295,
#    'end_char': 297,
#    'coref_chains': []},
#   {'id': 28,
#    'text': 'be',
#    'start_char': 298,
#    'end_char': 300,
#    'coref_chains': []},
#   {'id': 29,
#    'text': 'amazingly',
#    'start_char': 301,
#    'end_char': 310,
#    'coref_chains': []},
#   {'id': 30,
#    'text': 'efficient',
#    'start_char': 311,
#    'end_char': 320,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 31,
#    'text': ';',
#    'start_char': 320,
#    'end_char': 321,
#    'coref_chains': []},
#   {'id': 32,
#    'text': 'their',
#    'start_char': 322,
#    'end_char': 327,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b1190>,
#     <stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b11f0>]},
#   {'id': 33,
#    'text': 'counterparts',
#    'start_char': 328,
#    'end_char': 340,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b1250>]},
#   {'id': 34,
#    'text': 'for',
#    'start_char': 341,
#    'end_char': 344,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b12b0>]},
#   {'id': 35,
#    'text': 'a',
#    'start_char': 345,
#    'end_char': 346,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b1310>]},
#   {'id': 36,
#    'text': 'multi-step',
#    'start_char': 347,
#    'end_char': 357,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b1370>]},
#   {'id': 37,
#    'text': 'ahead',
#    'start_char': 358,
#    'end_char': 363,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b13d0>]},
#   {'id': 38,
#    'text': '(',
#    'start_char': 364,
#    'end_char': 365,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b1430>],
#    'misc': 'SpaceAfter=No'},
#   {'id': 39,
#    'text': 'MSA',
#    'start_char': 365,
#    'end_char': 368,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b1490>],
#    'misc': 'SpaceAfter=No'},
#   {'id': 40,
#    'text': ')',
#    'start_char': 368,
#    'end_char': 369,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b14f0>]},
#   {'id': 41,
#    'text': 'prediction',
#    'start_char': 370,
#    'end_char': 380,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b1550>]},
#   {'id': 42,
#    'text': 'are',
#    'start_char': 381,
#    'end_char': 384,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b1610>]},
#   {'id': 43,
#    'text': 'still',
#    'start_char': 385,
#    'end_char': 390,
#    'coref_chains': []},
#   {'id': 44,
#    'text': 'in',
#    'start_char': 391,
#    'end_char': 393,
#    'coref_chains': []},
#   {'id': 45,
#    'text': 'their',
#    'start_char': 394,
#    'end_char': 399,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b15b0>]},
#   {'id': 46,
#    'text': 'infancy',
#    'start_char': 400,
#    'end_char': 407,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 47,
#    'text': '.',
#    'start_char': 407,
#    'end_char': 408,
#    'coref_chains': []}],
#  [{'id': 1,
#    'text': 'One',
#    'start_char': 409,
#    'end_char': 412,
#    'coref_chains': []},
#   {'id': 2,
#    'text': 'may',
#    'start_char': 413,
#    'end_char': 416,
#    'coref_chains': []},
#   {'id': 3,
#    'text': 'attribute',
#    'start_char': 417,
#    'end_char': 426,
#    'coref_chains': []},
#   {'id': 4,
#    'text': 'this',
#    'start_char': 427,
#    'end_char': 431,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b1670>]},
#   {'id': 5,
#    'text': 'fact',
#    'start_char': 432,
#    'end_char': 436,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b16d0>]},
#   {'id': 6,
#    'text': 'to',
#    'start_char': 437,
#    'end_char': 439,
#    'coref_chains': []},
#   {'id': 7,
#    'text': 'an',
#    'start_char': 440,
#    'end_char': 442,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b1730>]},
#   {'id': 8,
#    'text': 'exponential',
#    'start_char': 443,
#    'end_char': 454,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b1790>]},
#   {'id': 9,
#    'text': 'growth',
#    'start_char': 455,
#    'end_char': 461,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b17f0>]},
#   {'id': 10,
#    'text': 'of',
#    'start_char': 462,
#    'end_char': 464,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b1850>]},
#   {'id': 11,
#    'text': 'an',
#    'start_char': 465,
#    'end_char': 467,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b18b0>]},
#   {'id': 12,
#    'text': 'average',
#    'start_char': 468,
#    'end_char': 475,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b1910>]},
#   {'id': 13,
#    'text': 'prediction',
#    'start_char': 476,
#    'end_char': 486,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b1970>]},
#   {'id': 14,
#    'text': 'error',
#    'start_char': 487,
#    'end_char': 492,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b1a30>]},
#   {'id': 15,
#    'text': 'with',
#    'start_char': 493,
#    'end_char': 497,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b1a90>]},
#   {'id': 16,
#    'text': 'a',
#    'start_char': 498,
#    'end_char': 499,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b1af0>]},
#   {'id': 17,
#    'text': 'prediction',
#    'start_char': 500,
#    'end_char': 510,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b1b50>]},
#   {'id': 18,
#    'text': 'horizon',
#    'start_char': 511,
#    'end_char': 518,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b1bb0>],
#    'misc': 'SpaceAfter=No'},
#   {'id': 19,
#    'text': ',',
#    'start_char': 518,
#    'end_char': 519,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b1c10>]},
#   {'id': 20,
#    'text': 'that',
#    'start_char': 520,
#    'end_char': 524,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b1c70>]},
#   {'id': 21,
#    'text': 'is',
#    'start_char': 525,
#    'end_char': 527,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b1cd0>]},
#   {'id': 22,
#    'text': 'the',
#    'start_char': 528,
#    'end_char': 531,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b1d30>]},
#   {'id': 23,
#    'text': 'number',
#    'start_char': 532,
#    'end_char': 538,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b1d90>]},
#   {'id': 24,
#    'text': 'of',
#    'start_char': 539,
#    'end_char': 541,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b1df0>]},
#   {'id': 25,
#    'text': 'steps',
#    'start_char': 542,
#    'end_char': 547,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b1f70>]},
#   {'id': 26,
#    'text': 'ahead',
#    'start_char': 548,
#    'end_char': 553,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b0070>]},
#   {'id': 27,
#    'text': 'to',
#    'start_char': 554,
#    'end_char': 556,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b00d0>]},
#   {'id': 28,
#    'text': 'be',
#    'start_char': 557,
#    'end_char': 559,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b01f0>]},
#   {'id': 29,
#    'text': 'predicted',
#    'start_char': 560,
#    'end_char': 569,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b02b0>],
#    'misc': 'SpaceAfter=No'},
#   {'id': 30,
#    'text': '.',
#    'start_char': 569,
#    'end_char': 570,
#    'coref_chains': [],
#    'misc': 'SpacesAfter=\\s\\n'}],
#  [{'id': 1,
#    'text': 'This',
#    'start_char': 572,
#    'end_char': 576,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b0310>]},
#   {'id': 2,
#    'text': 'exponential',
#    'start_char': 577,
#    'end_char': 588,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b0370>]},
#   {'id': 3,
#    'text': 'growth',
#    'start_char': 589,
#    'end_char': 595,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b03d0>]},
#   {'id': 4,
#    'text': 'reflects',
#    'start_char': 596,
#    'end_char': 604,
#    'coref_chains': []},
#   {'id': 5,
#    'text': 'Lyapunov',
#    'start_char': 605,
#    'end_char': 613,
#    'coref_chains': []},
#   {'id': 6,
#    'text': 'instability',
#    'start_char': 614,
#    'end_char': 625,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 7,
#    'text': ',',
#    'start_char': 625,
#    'end_char': 626,
#    'coref_chains': []},
#   {'id': 8,
#    'text': 'immanent',
#    'start_char': 627,
#    'end_char': 635,
#    'coref_chains': []},
#   {'id': 9,
#    'text': 'to',
#    'start_char': 636,
#    'end_char': 638,
#    'coref_chains': []},
#   {'id': 10,
#    'text': 'any',
#    'start_char': 639,
#    'end_char': 642,
#    'coref_chains': []},
#   {'id': 11,
#    'text': 'chaotic',
#    'start_char': 643,
#    'end_char': 650,
#    'coref_chains': []},
#   {'id': 12,
#    'text': 'system',
#    'start_char': 651,
#    'end_char': 657,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 13,
#    'text': '.',
#    'start_char': 657,
#    'end_char': 658,
#    'coref_chains': []}],
#  [{'id': 1,
#    'text': 'Namely',
#    'start_char': 659,
#    'end_char': 665,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 2,
#    'text': ',',
#    'start_char': 665,
#    'end_char': 666,
#    'coref_chains': []},
#   {'id': 3,
#    'text': 'according',
#    'start_char': 667,
#    'end_char': 676,
#    'coref_chains': []},
#   {'id': 4,
#    'text': 'to',
#    'start_char': 677,
#    'end_char': 679,
#    'coref_chains': []},
#   {'id': 5,
#    'text': 'Lyapunov',
#    'start_char': 680,
#    'end_char': 688,
#    'coref_chains': []},
#   {'id': 6,
#    'text': 'instability',
#    'start_char': 689,
#    'end_char': 700,
#    'coref_chains': []},
#   {'id': 7,
#    'text': 'definition',
#    'start_char': 701,
#    'end_char': 711,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 8,
#    'text': ',',
#    'start_char': 711,
#    'end_char': 712,
#    'coref_chains': []},
#   {'id': 9,
#    'text': 'however',
#    'start_char': 713,
#    'end_char': 720,
#    'coref_chains': []},
#   {'id': 10,
#    'text': 'small',
#    'start_char': 721,
#    'end_char': 726,
#    'coref_chains': []},
#   {'id': 11,
#    'text': 'is',
#    'start_char': 727,
#    'end_char': 729,
#    'coref_chains': []},
#   {'id': 12,
#    'text': 'any',
#    'start_char': 730,
#    'end_char': 733,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b0850>]},
#   {'id': 13,
#    'text': 'initial',
#    'start_char': 734,
#    'end_char': 741,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b08b0>]},
#   {'id': 14,
#    'text': 'difference',
#    'start_char': 742,
#    'end_char': 752,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b0910>]},
#   {'id': 15,
#    'text': 'between',
#    'start_char': 753,
#    'end_char': 760,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b0970>]},
#   {'id': 16,
#    'text': 'two',
#    'start_char': 761,
#    'end_char': 764,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b09d0>]},
#   {'id': 17,
#    'text': 'neighbouring',
#    'start_char': 765,
#    'end_char': 777,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b0a30>]},
#   {'id': 18,
#    'text': 'trajectories',
#    'start_char': 778,
#    'end_char': 790,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b0a90>],
#    'misc': 'SpaceAfter=No'},
#   {'id': 19,
#    'text': ',',
#    'start_char': 790,
#    'end_char': 791,
#    'coref_chains': []},
#   {'id': 20,
#    'text': 'the',
#    'start_char': 792,
#    'end_char': 795,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b0af0>]},
#   {'id': 21,
#    'text': 'difference',
#    'start_char': 796,
#    'end_char': 806,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b0b50>]},
#   {'id': 22,
#    'text': 'grows',
#    'start_char': 807,
#    'end_char': 812,
#    'coref_chains': []},
#   {'id': 23,
#    'text': 'exponentially',
#    'start_char': 813,
#    'end_char': 826,
#    'coref_chains': []},
#   {'id': 24,
#    'text': 'with',
#    'start_char': 827,
#    'end_char': 831,
#    'coref_chains': []},
#   {'id': 25,
#    'text': 'time',
#    'start_char': 832,
#    'end_char': 836,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 26,
#    'text': ',',
#    'start_char': 836,
#    'end_char': 837,
#    'coref_chains': []},
#   {'id': 27,
#    'text': 'and',
#    'start_char': 838,
#    'end_char': 841,
#    'coref_chains': []},
#   {'id': 28,
#    'text': 'its',
#    'start_char': 842,
#    'end_char': 845,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b0bb0>]},
#   {'id': 29,
#    'text': 'exponent',
#    'start_char': 846,
#    'end_char': 854,
#    'coref_chains': []},
#   {'id': 30,
#    'text': 'equals',
#    'start_char': 855,
#    'end_char': 861,
#    'coref_chains': []},
#   {'id': 31,
#    'text': 'to',
#    'start_char': 862,
#    'end_char': 864,
#    'coref_chains': []},
#   {'id': 32,
#    'text': 'the',
#    'start_char': 865,
#    'end_char': 868,
#    'coref_chains': []},
#   {'id': 33,
#    'text': 'highest',
#    'start_char': 869,
#    'end_char': 876,
#    'coref_chains': []},
#   {'id': 34,
#    'text': 'Lyapunov',
#    'start_char': 877,
#    'end_char': 885,
#    'coref_chains': []},
#   {'id': 35,
#    'text': 'exponent',
#    'start_char': 886,
#    'end_char': 894,
#    'coref_chains': []},
#   {'id': 36,
#    'text': '(',
#    'start_char': 895,
#    'end_char': 896,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 37,
#    'text': 'Kantz',
#    'start_char': 896,
#    'end_char': 901,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b0c10>,
#     <stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b0cd0>]},
#   {'id': 38,
#    'text': '&',
#    'start_char': 902,
#    'end_char': 903,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b0d30>]},
#   {'id': 39,
#    'text': 'Schreiber',
#    'start_char': 904,
#    'end_char': 913,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b0d90>,
#     <stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b0f10>],
#    'misc': 'SpaceAfter=No'},
#   {'id': 40,
#    'text': ',',
#    'start_char': 913,
#    'end_char': 914,
#    'coref_chains': []},
#   {'id': 41,
#    'text': '2003',
#    'start_char': 915,
#    'end_char': 919,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b0fd0>],
#    'misc': 'SpaceAfter=No'},
#   {'id': 42,
#    'text': ';',
#    'start_char': 919,
#    'end_char': 920,
#    'coref_chains': []},
#   {'id': 43,
#    'text': 'Malinetskii',
#    'start_char': 921,
#    'end_char': 932,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b70d0>]},
#   {'id': 44,
#    'text': '&',
#    'start_char': 933,
#    'end_char': 934,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b7190>]},
#   {'id': 45,
#    'text': 'Potapov',
#    'start_char': 935,
#    'end_char': 942,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b71f0>,
#     <stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b7370>],
#    'misc': 'SpaceAfter=No'},
#   {'id': 46,
#    'text': ',',
#    'start_char': 942,
#    'end_char': 943,
#    'coref_chains': []},
#   {'id': 47,
#    'text': '2000',
#    'start_char': 944,
#    'end_char': 948,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b7430>],
#    'misc': 'SpaceAfter=No'},
#   {'id': 48,
#    'text': ')',
#    'start_char': 948,
#    'end_char': 949,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 49,
#    'text': '.',
#    'start_char': 949,
#    'end_char': 950,
#    'coref_chains': []}],
#  [{'id': 1,
#    'text': 'Laypunov',
#    'start_char': 951,
#    'end_char': 959,
#    'coref_chains': []},
#   {'id': 2,
#    'text': 'instability',
#    'start_char': 960,
#    'end_char': 971,
#    'coref_chains': []},
#   {'id': 3,
#    'text': 'also',
#    'start_char': 972,
#    'end_char': 976,
#    'coref_chains': []},
#   {'id': 4,
#    'text': 'leads',
#    'start_char': 977,
#    'end_char': 982,
#    'coref_chains': []},
#   {'id': 5,
#    'text': 'to',
#    'start_char': 983,
#    'end_char': 985,
#    'coref_chains': []},
#   {'id': 6,
#    'text': 'another',
#    'start_char': 986,
#    'end_char': 993,
#    'coref_chains': []},
#   {'id': 7,
#    'text': 'concept',
#    'start_char': 994,
#    'end_char': 1001,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 8,
#    'text': ',',
#    'start_char': 1001,
#    'end_char': 1002,
#    'coref_chains': []},
#   {'id': 9,
#    'text': 'that',
#    'start_char': 1003,
#    'end_char': 1007,
#    'coref_chains': []},
#   {'id': 10,
#    'text': 'of',
#    'start_char': 1008,
#    'end_char': 1010,
#    'coref_chains': []},
#   {'id': 11,
#    'text': 'a',
#    'start_char': 1011,
#    'end_char': 1012,
#    'coref_chains': []},
#   {'id': 12,
#    'text': 'horizon',
#    'start_char': 1013,
#    'end_char': 1020,
#    'coref_chains': []},
#   {'id': 13,
#    'text': 'of',
#    'start_char': 1021,
#    'end_char': 1023,
#    'coref_chains': []},
#   {'id': 14,
#    'text': 'predictability',
#    'start_char': 1024,
#    'end_char': 1038,
#    'coref_chains': []},
#   {'id': 15,
#    'text': '(',
#    'start_char': 1039,
#    'end_char': 1040,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 16,
#    'text': 'sometimes',
#    'start_char': 1040,
#    'end_char': 1049,
#    'coref_chains': []},
#   {'id': 17,
#    'text': 'also',
#    'start_char': 1050,
#    'end_char': 1054,
#    'coref_chains': []},
#   {'id': 18,
#    'text': 'referred',
#    'start_char': 1055,
#    'end_char': 1063,
#    'coref_chains': []},
#   {'id': 19,
#    'text': 'to',
#    'start_char': 1064,
#    'end_char': 1066,
#    'coref_chains': []},
#   {'id': 20,
#    'text': 'as',
#    'start_char': 1067,
#    'end_char': 1069,
#    'coref_chains': []},
#   {'id': 21,
#    'text': 'Lyapunov',
#    'start_char': 1070,
#    'end_char': 1078,
#    'coref_chains': []},
#   {'id': 22,
#    'text': 'time',
#    'start_char': 1079,
#    'end_char': 1083,
#    'coref_chains': []},
#   {'id': 23,
#    'text': '(',
#    'start_char': 1084,
#    'end_char': 1085,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 24,
#    'text': 'Bezruchko',
#    'start_char': 1085,
#    'end_char': 1094,
#    'coref_chains': []},
#   {'id': 25,
#    'text': '&',
#    'start_char': 1095,
#    'end_char': 1096,
#    'coref_chains': []},
#   {'id': 26,
#    'text': 'Smirnov',
#    'start_char': 1097,
#    'end_char': 1104,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 27,
#    'text': ',',
#    'start_char': 1104,
#    'end_char': 1105,
#    'coref_chains': []},
#   {'id': 28,
#    'text': '2010',
#    'start_char': 1106,
#    'end_char': 1110,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 29,
#    'text': ')',
#    'start_char': 1110,
#    'end_char': 1111,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 30,
#    'text': ')',
#    'start_char': 1111,
#    'end_char': 1112,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 31,
#    'text': '.',
#    'start_char': 1112,
#    'end_char': 1113,
#    'coref_chains': []}],
#  [{'id': 1,
#    'text': 'For',
#    'start_char': 1114,
#    'end_char': 1117,
#    'coref_chains': []},
#   {'id': 2,
#    'text': 'a',
#    'start_char': 1118,
#    'end_char': 1119,
#    'coref_chains': []},
#   {'id': 3,
#    'text': 'given',
#    'start_char': 1120,
#    'end_char': 1125,
#    'coref_chains': []},
#   {'id': 4,
#    'text': 'observational',
#    'start_char': 1126,
#    'end_char': 1139,
#    'coref_chains': []},
#   {'id': 5,
#    'text': 'error',
#    'start_char': 1140,
#    'end_char': 1145,
#    'coref_chains': [],
#    'misc': 'SpacesAfter=\\s\\s'},
#   {'id': 6,
#    'text': 'and',
#    'start_char': 1147,
#    'end_char': 1150,
#    'coref_chains': []},
#   {'id': 7,
#    'text': 'the',
#    'start_char': 1151,
#    'end_char': 1154,
#    'coref_chains': []},
#   {'id': 8,
#    'text': 'maximum',
#    'start_char': 1155,
#    'end_char': 1162,
#    'coref_chains': []},
#   {'id': 9,
#    'text': 'prediction',
#    'start_char': 1163,
#    'end_char': 1173,
#    'coref_chains': []},
#   {'id': 10,
#    'text': 'error',
#    'start_char': 1174,
#    'end_char': 1179,
#    'coref_chains': []},
#   {'id': 11,
#    'text': ',',
#    'start_char': 1180,
#    'end_char': 1181,
#    'coref_chains': []},
#   {'id': 12,
#    'text': 'the',
#    'start_char': 1182,
#    'end_char': 1185,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b0430>]},
#   {'id': 13,
#    'text': 'exponential',
#    'start_char': 1186,
#    'end_char': 1197,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b0490>]},
#   {'id': 14,
#    'text': 'growth',
#    'start_char': 1198,
#    'end_char': 1204,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b04f0>]},
#   {'id': 15,
#    'text': 'mentioned',
#    'start_char': 1205,
#    'end_char': 1214,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b0550>]},
#   {'id': 16,
#    'text': 'above',
#    'start_char': 1215,
#    'end_char': 1220,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b05b0>]},
#   {'id': 17,
#    'text': 'satisfies',
#    'start_char': 1221,
#    'end_char': 1230,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 18,
#    'text': ',',
#    'start_char': 1230,
#    'end_char': 1231,
#    'coref_chains': []},
#   {'id': 19,
#    'text': 'thereby',
#    'start_char': 1232,
#    'end_char': 1239,
#    'coref_chains': []},
#   {'id': 20,
#    'text': 'giving',
#    'start_char': 1240,
#    'end_char': 1246,
#    'coref_chains': []},
#   {'id': 21,
#    'text': 'a',
#    'start_char': 1247,
#    'end_char': 1248,
#    'coref_chains': []},
#   {'id': 22,
#    'text': 'horizon',
#    'start_char': 1249,
#    'end_char': 1256,
#    'coref_chains': []},
#   {'id': 23,
#    'text': 'of',
#    'start_char': 1257,
#    'end_char': 1259,
#    'coref_chains': []},
#   {'id': 24,
#    'text': 'predictability',
#    'start_char': 1260,
#    'end_char': 1274,
#    'coref_chains': [],
#    'misc': 'SpacesAfter=\\s\\s'},
#   {'id': 25,
#    'text': '(',
#    'start_char': 1276,
#    'end_char': 1277,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 26,
#    'text': 'Kantz',
#    'start_char': 1277,
#    'end_char': 1282,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b0c70>,
#     <stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b0df0>]},
#   {'id': 27,
#    'text': '&',
#    'start_char': 1283,
#    'end_char': 1284,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b0e50>]},
#   {'id': 28,
#    'text': 'Schreiber',
#    'start_char': 1285,
#    'end_char': 1294,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b0eb0>,
#     <stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b0f70>],
#    'misc': 'SpaceAfter=No'},
#   {'id': 29,
#    'text': ',',
#    'start_char': 1294,
#    'end_char': 1295,
#    'coref_chains': []},
#   {'id': 30,
#    'text': '2003',
#    'start_char': 1296,
#    'end_char': 1300,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b7070>],
#    'misc': 'SpaceAfter=No'},
#   {'id': 31,
#    'text': ';',
#    'start_char': 1300,
#    'end_char': 1301,
#    'coref_chains': []},
#   {'id': 32,
#    'text': 'Malinetskii',
#    'start_char': 1302,
#    'end_char': 1313,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b7250>]},
#   {'id': 33,
#    'text': '&',
#    'start_char': 1314,
#    'end_char': 1315,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b72b0>]},
#   {'id': 34,
#    'text': 'Potapov',
#    'start_char': 1316,
#    'end_char': 1323,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b7310>,
#     <stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b73d0>],
#    'misc': 'SpaceAfter=No'},
#   {'id': 35,
#    'text': ',',
#    'start_char': 1323,
#    'end_char': 1324,
#    'coref_chains': []},
#   {'id': 36,
#    'text': '2000',
#    'start_char': 1325,
#    'end_char': 1329,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b7490>],
#    'misc': 'SpaceAfter=No'},
#   {'id': 37,
#    'text': ')',
#    'start_char': 1329,
#    'end_char': 1330,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 38,
#    'text': '.',
#    'start_char': 1330,
#    'end_char': 1331,
#    'coref_chains': []}],
#  [{'id': 1,
#    'text': 'In',
#    'start_char': 1332,
#    'end_char': 1334,
#    'coref_chains': []},
#   {'id': 2,
#    'text': 'the',
#    'start_char': 1335,
#    'end_char': 1338,
#    'coref_chains': []},
#   {'id': 3,
#    'text': 'context',
#    'start_char': 1339,
#    'end_char': 1346,
#    'coref_chains': []},
#   {'id': 4,
#    'text': 'of',
#    'start_char': 1347,
#    'end_char': 1349,
#    'coref_chains': []},
#   {'id': 5,
#    'text': 'a',
#    'start_char': 1350,
#    'end_char': 1351,
#    'coref_chains': []},
#   {'id': 6,
#    'text': 'multi-step',
#    'start_char': 1352,
#    'end_char': 1362,
#    'coref_chains': []},
#   {'id': 7,
#    'text': 'ahead',
#    'start_char': 1363,
#    'end_char': 1368,
#    'coref_chains': []},
#   {'id': 8,
#    'text': 'prediction',
#    'start_char': 1369,
#    'end_char': 1379,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 9,
#    'text': ',',
#    'start_char': 1379,
#    'end_char': 1380,
#    'coref_chains': []},
#   {'id': 10,
#    'text': 'this',
#    'start_char': 1381,
#    'end_char': 1385,
#    'coref_chains': []},
#   {'id': 11,
#    'text': 'implies',
#    'start_char': 1386,
#    'end_char': 1393,
#    'coref_chains': []},
#   {'id': 12,
#    'text': 'that',
#    'start_char': 1394,
#    'end_char': 1398,
#    'coref_chains': []},
#   {'id': 13,
#    'text': 'the',
#    'start_char': 1399,
#    'end_char': 1402,
#    'coref_chains': []},
#   {'id': 14,
#    'text': 'smallest',
#    'start_char': 1403,
#    'end_char': 1411,
#    'coref_chains': []},
#   {'id': 15,
#    'text': 'difference',
#    'start_char': 1412,
#    'end_char': 1422,
#    'coref_chains': []},
#   {'id': 16,
#    'text': 'between',
#    'start_char': 1423,
#    'end_char': 1430,
#    'coref_chains': []},
#   {'id': 17,
#    'text': 'true',
#    'start_char': 1431,
#    'end_char': 1435,
#    'coref_chains': []},
#   {'id': 18,
#    'text': 'and',
#    'start_char': 1436,
#    'end_char': 1439,
#    'coref_chains': []},
#   {'id': 19,
#    'text': 'predicted',
#    'start_char': 1440,
#    'end_char': 1449,
#    'coref_chains': []},
#   {'id': 20,
#    'text': 'values',
#    'start_char': 1450,
#    'end_char': 1456,
#    'coref_chains': []},
#   {'id': 21,
#    'text': 'in',
#    'start_char': 1457,
#    'end_char': 1459,
#    'coref_chains': []},
#   {'id': 22,
#    'text': 'an',
#    'start_char': 1460,
#    'end_char': 1462,
#    'coref_chains': []},
#   {'id': 23,
#    'text': 'intermediate',
#    'start_char': 1463,
#    'end_char': 1475,
#    'coref_chains': []},
#   {'id': 24,
#    'text': 'point',
#    'start_char': 1476,
#    'end_char': 1481,
#    'coref_chains': []},
#   {'id': 25,
#    'text': '(',
#    'start_char': 1482,
#    'end_char': 1483,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 26,
#    'text': 'that',
#    'start_char': 1483,
#    'end_char': 1487,
#    'coref_chains': []},
#   {'id': 27,
#    'text': 'is',
#    'start_char': 1488,
#    'end_char': 1490,
#    'coref_chains': []},
#   {'id': 28,
#    'text': 'the',
#    'start_char': 1491,
#    'end_char': 1494,
#    'coref_chains': []},
#   {'id': 29,
#    'text': 'point',
#    'start_char': 1495,
#    'end_char': 1500,
#    'coref_chains': []},
#   {'id': 30,
#    'text': 'between',
#    'start_char': 1501,
#    'end_char': 1508,
#    'coref_chains': []},
#   {'id': 31,
#    'text': 'the',
#    'start_char': 1509,
#    'end_char': 1512,
#    'coref_chains': []},
#   {'id': 32,
#    'text': 'last',
#    'start_char': 1513,
#    'end_char': 1517,
#    'coref_chains': []},
#   {'id': 33,
#    'text': 'observable',
#    'start_char': 1518,
#    'end_char': 1528,
#    'coref_chains': []},
#   {'id': 34,
#    'text': 'point',
#    'start_char': 1529,
#    'end_char': 1534,
#    'coref_chains': []},
#   {'id': 35,
#    'text': 'and',
#    'start_char': 1535,
#    'end_char': 1538,
#    'coref_chains': []},
#   {'id': 36,
#    'text': 'the',
#    'start_char': 1539,
#    'end_char': 1542,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b74f0>]},
#   {'id': 37,
#    'text': 'point',
#    'start_char': 1543,
#    'end_char': 1548,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b7550>]},
#   {'id': 38,
#    'text': 'to',
#    'start_char': 1549,
#    'end_char': 1551,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b75b0>]},
#   {'id': 39,
#    'text': 'be',
#    'start_char': 1552,
#    'end_char': 1554,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b7610>]},
#   {'id': 40,
#    'text': 'predicted',
#    'start_char': 1555,
#    'end_char': 1564,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b7670>],
#    'misc': 'SpaceAfter=No'},
#   {'id': 41,
#    'text': ')',
#    'start_char': 1564,
#    'end_char': 1565,
#    'coref_chains': []},
#   {'id': 42,
#    'text': '–',
#    'start_char': 1566,
#    'end_char': 1567,
#    'coref_chains': []},
#   {'id': 43,
#    'text': 'inevitable',
#    'start_char': 1568,
#    'end_char': 1578,
#    'coref_chains': []},
#   {'id': 44,
#    'text': 'for',
#    'start_char': 1579,
#    'end_char': 1582,
#    'coref_chains': []},
#   {'id': 45,
#    'text': 'any',
#    'start_char': 1583,
#    'end_char': 1586,
#    'coref_chains': []},
#   {'id': 46,
#    'text': 'prediction',
#    'start_char': 1587,
#    'end_char': 1597,
#    'coref_chains': []},
#   {'id': 47,
#    'text': 'method',
#    'start_char': 1598,
#    'end_char': 1604,
#    'coref_chains': []},
#   {'id': 48,
#    'text': '–',
#    'start_char': 1605,
#    'end_char': 1606,
#    'coref_chains': []},
#   {'id': 49,
#    'text': 'triggers',
#    'start_char': 1607,
#    'end_char': 1615,
#    'coref_chains': []},
#   {'id': 50,
#    'text': 'exponential',
#    'start_char': 1616,
#    'end_char': 1627,
#    'coref_chains': []},
#   {'id': 51,
#    'text': 'error',
#    'start_char': 1628,
#    'end_char': 1633,
#    'coref_chains': []},
#   {'id': 52,
#    'text': 'growth',
#    'start_char': 1634,
#    'end_char': 1640,
#    'coref_chains': []},
#   {'id': 53,
#    'text': 'in',
#    'start_char': 1641,
#    'end_char': 1643,
#    'coref_chains': []},
#   {'id': 54,
#    'text': 'all',
#    'start_char': 1644,
#    'end_char': 1647,
#    'coref_chains': []},
#   {'id': 55,
#    'text': 'subsequent',
#    'start_char': 1648,
#    'end_char': 1658,
#    'coref_chains': []},
#   {'id': 56,
#    'text': 'intermediate',
#    'start_char': 1659,
#    'end_char': 1671,
#    'coref_chains': []},
#   {'id': 57,
#    'text': 'points',
#    'start_char': 1672,
#    'end_char': 1678,
#    'coref_chains': []},
#   {'id': 58,
#    'text': 'and',
#    'start_char': 1679,
#    'end_char': 1682,
#    'coref_chains': []},
#   {'id': 59,
#    'text': 'in',
#    'start_char': 1683,
#    'end_char': 1685,
#    'coref_chains': []},
#   {'id': 60,
#    'text': 'the',
#    'start_char': 1686,
#    'end_char': 1689,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b76d0>]},
#   {'id': 61,
#    'text': 'point',
#    'start_char': 1690,
#    'end_char': 1695,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b7730>]},
#   {'id': 62,
#    'text': 'to',
#    'start_char': 1696,
#    'end_char': 1698,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b7790>]},
#   {'id': 63,
#    'text': 'be',
#    'start_char': 1699,
#    'end_char': 1701,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b77f0>]},
#   {'id': 64,
#    'text': 'predicted',
#    'start_char': 1702,
#    'end_char': 1711,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b7850>]},
#   {'id': 65,
#    'text': 'itself',
#    'start_char': 1712,
#    'end_char': 1718,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b78b0>,
#     <stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b7910>],
#    'misc': 'SpaceAfter=No'},
#   {'id': 66,
#    'text': '.',
#    'start_char': 1718,
#    'end_char': 1719,
#    'coref_chains': []}],
#  [{'id': 1,
#    'text': 'Therefore',
#    'start_char': 1720,
#    'end_char': 1729,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 2,
#    'text': ',',
#    'start_char': 1729,
#    'end_char': 1730,
#    'coref_chains': []},
#   {'id': 3,
#    'text': 'a',
#    'start_char': 1731,
#    'end_char': 1732,
#    'coref_chains': []},
#   {'id': 4,
#    'text': 'horizon',
#    'start_char': 1733,
#    'end_char': 1740,
#    'coref_chains': []},
#   {'id': 5,
#    'text': 'of',
#    'start_char': 1741,
#    'end_char': 1743,
#    'coref_chains': []},
#   {'id': 6,
#    'text': 'predictability',
#    'start_char': 1744,
#    'end_char': 1758,
#    'coref_chains': []},
#   {'id': 7,
#    'text': 'is',
#    'start_char': 1759,
#    'end_char': 1761,
#    'coref_chains': []},
#   {'id': 8,
#    'text': 'an',
#    'start_char': 1762,
#    'end_char': 1764,
#    'coref_chains': []},
#   {'id': 9,
#    'text': 'upper',
#    'start_char': 1765,
#    'end_char': 1770,
#    'coref_chains': []},
#   {'id': 10,
#    'text': 'theoretical',
#    'start_char': 1771,
#    'end_char': 1782,
#    'coref_chains': []},
#   {'id': 11,
#    'text': 'boundary',
#    'start_char': 1783,
#    'end_char': 1791,
#    'coref_chains': []},
#   {'id': 12,
#    'text': 'for',
#    'start_char': 1792,
#    'end_char': 1795,
#    'coref_chains': []},
#   {'id': 13,
#    'text': 'the',
#    'start_char': 1796,
#    'end_char': 1799,
#    'coref_chains': []},
#   {'id': 14,
#    'text': 'number',
#    'start_char': 1800,
#    'end_char': 1806,
#    'coref_chains': []},
#   {'id': 15,
#    'text': 'of',
#    'start_char': 1807,
#    'end_char': 1809,
#    'coref_chains': []},
#   {'id': 16,
#    'text': 'steps',
#    'start_char': 1810,
#    'end_char': 1815,
#    'coref_chains': []},
#   {'id': 17,
#    'text': 'ahead',
#    'start_char': 1816,
#    'end_char': 1821,
#    'coref_chains': []},
#   {'id': 18,
#    'text': 'to',
#    'start_char': 1822,
#    'end_char': 1824,
#    'coref_chains': []},
#   {'id': 19,
#    'text': 'be',
#    'start_char': 1825,
#    'end_char': 1827,
#    'coref_chains': []},
#   {'id': 20,
#    'text': 'predicted',
#    'start_char': 1828,
#    'end_char': 1837,
#    'coref_chains': []},
#   {'id': 21,
#    'text': 'for',
#    'start_char': 1838,
#    'end_char': 1841,
#    'coref_chains': []},
#   {'id': 22,
#    'text': 'any',
#    'start_char': 1842,
#    'end_char': 1845,
#    'coref_chains': []},
#   {'id': 23,
#    'text': 'prediction',
#    'start_char': 1846,
#    'end_char': 1856,
#    'coref_chains': []},
#   {'id': 24,
#    'text': 'algorithm',
#    'start_char': 1857,
#    'end_char': 1866,
#    'coref_chains': []},
#   {'id': 25,
#    'text': '(',
#    'start_char': 1867,
#    'end_char': 1868,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 26,
#    'text': 'for',
#    'start_char': 1868,
#    'end_char': 1871,
#    'coref_chains': []},
#   {'id': 27,
#    'text': 'given',
#    'start_char': 1872,
#    'end_char': 1877,
#    'coref_chains': [],
#    'misc': 'SpacesAfter=\\s\\s'},
#   {'id': 28,
#    'text': 'and',
#    'start_char': 1879,
#    'end_char': 1882,
#    'coref_chains': []},
#   {'id': 29,
#    'text': ')',
#    'start_char': 1883,
#    'end_char': 1884,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 30,
#    'text': '.',
#    'start_char': 1884,
#    'end_char': 1885,
#    'coref_chains': []}],
#  [{'id': 1,
#    'text': 'A',
#    'start_char': 1886,
#    'end_char': 1887,
#    'coref_chains': []},
#   {'id': 2,
#    'text': 'horizon',
#    'start_char': 1888,
#    'end_char': 1895,
#    'coref_chains': []},
#   {'id': 3,
#    'text': 'of',
#    'start_char': 1896,
#    'end_char': 1898,
#    'coref_chains': []},
#   {'id': 4,
#    'text': 'predictability',
#    'start_char': 1899,
#    'end_char': 1913,
#    'coref_chains': []},
#   {'id': 5,
#    'text': 'should',
#    'start_char': 1914,
#    'end_char': 1920,
#    'coref_chains': []},
#   {'id': 6,
#    'text': 'not',
#    'start_char': 1921,
#    'end_char': 1924,
#    'coref_chains': []},
#   {'id': 7,
#    'text': 'be',
#    'start_char': 1925,
#    'end_char': 1927,
#    'coref_chains': []},
#   {'id': 8,
#    'text': 'confused',
#    'start_char': 1928,
#    'end_char': 1936,
#    'coref_chains': []},
#   {'id': 9,
#    'text': 'with',
#    'start_char': 1937,
#    'end_char': 1941,
#    'coref_chains': []},
#   {'id': 10,
#    'text': 'a',
#    'start_char': 1942,
#    'end_char': 1943,
#    'coref_chains': []},
#   {'id': 11,
#    'text': 'prediction',
#    'start_char': 1944,
#    'end_char': 1954,
#    'coref_chains': []},
#   {'id': 12,
#    'text': 'horizon',
#    'start_char': 1955,
#    'end_char': 1962,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 13,
#    'text': ',',
#    'start_char': 1962,
#    'end_char': 1963,
#    'coref_chains': []},
#   {'id': 14,
#    'text': 'which',
#    'start_char': 1964,
#    'end_char': 1969,
#    'coref_chains': []},
#   {'id': 15,
#    'text': 'is',
#    'start_char': 1970,
#    'end_char': 1972,
#    'coref_chains': []},
#   {'id': 16,
#    'text': 'a',
#    'start_char': 1973,
#    'end_char': 1974,
#    'coref_chains': []},
#   {'id': 17,
#    'text': 'mere',
#    'start_char': 1975,
#    'end_char': 1979,
#    'coref_chains': []},
#   {'id': 18,
#    'text': 'number',
#    'start_char': 1980,
#    'end_char': 1986,
#    'coref_chains': []},
#   {'id': 19,
#    'text': 'of',
#    'start_char': 1987,
#    'end_char': 1989,
#    'coref_chains': []},
#   {'id': 20,
#    'text': 'steps',
#    'start_char': 1990,
#    'end_char': 1995,
#    'coref_chains': []},
#   {'id': 21,
#    'text': 'ahead',
#    'start_char': 1996,
#    'end_char': 2001,
#    'coref_chains': []},
#   {'id': 22,
#    'text': 'the',
#    'start_char': 2002,
#    'end_char': 2005,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b7970>]},
#   {'id': 23,
#    'text': 'algorithm',
#    'start_char': 2006,
#    'end_char': 2015,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b79d0>]},
#   {'id': 24,
#    'text': 'makes',
#    'start_char': 2016,
#    'end_char': 2021,
#    'coref_chains': []},
#   {'id': 25,
#    'text': 'its',
#    'start_char': 2022,
#    'end_char': 2025,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b7a90>]},
#   {'id': 26,
#    'text': 'prediction',
#    'start_char': 2026,
#    'end_char': 2036,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 27,
#    'text': '.',
#    'start_char': 2036,
#    'end_char': 2037,
#    'coref_chains': []}],
#  [{'id': 1,
#    'text': 'Usually',
#    'start_char': 2038,
#    'end_char': 2045,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 2,
#    'text': ',',
#    'start_char': 2045,
#    'end_char': 2046,
#    'coref_chains': []},
#   {'id': 3,
#    'text': 'a',
#    'start_char': 2047,
#    'end_char': 2048,
#    'coref_chains': []},
#   {'id': 4,
#    'text': 'prediction',
#    'start_char': 2049,
#    'end_char': 2059,
#    'coref_chains': []},
#   {'id': 5,
#    'text': 'horizon',
#    'start_char': 2060,
#    'end_char': 2067,
#    'coref_chains': [],
#    'misc': 'SpacesAfter=\\s\\s'},
#   {'id': 6,
#    'text': 'is',
#    'start_char': 2069,
#    'end_char': 2071,
#    'coref_chains': []},
#   {'id': 7,
#    'text': 'essentially',
#    'start_char': 2072,
#    'end_char': 2083,
#    'coref_chains': []},
#   {'id': 8,
#    'text': 'lesser',
#    'start_char': 2084,
#    'end_char': 2090,
#    'coref_chains': []},
#   {'id': 9,
#    'text': 'than',
#    'start_char': 2091,
#    'end_char': 2095,
#    'coref_chains': []},
#   {'id': 10,
#    'text': 'a',
#    'start_char': 2096,
#    'end_char': 2097,
#    'coref_chains': []},
#   {'id': 11,
#    'text': 'horizon',
#    'start_char': 2098,
#    'end_char': 2105,
#    'coref_chains': []},
#   {'id': 12,
#    'text': 'of',
#    'start_char': 2106,
#    'end_char': 2108,
#    'coref_chains': []},
#   {'id': 13,
#    'text': 'predictability',
#    'start_char': 2109,
#    'end_char': 2123,
#    'coref_chains': []},
#   {'id': 14,
#    'text': ':',
#    'start_char': 2124,
#    'end_char': 2125,
#    'coref_chains': []},
#   {'id': 15,
#    'text': '.',
#    'start_char': 2126,
#    'end_char': 2127,
#    'coref_chains': [],
#    'misc': 'SpacesAfter=\\n'}],
#  [{'id': 1,
#    'text': 'Nonetheless',
#    'start_char': 2128,
#    'end_char': 2139,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 2,
#    'text': ',',
#    'start_char': 2139,
#    'end_char': 2140,
#    'coref_chains': []},
#   {'id': 3,
#    'text': 'this',
#    'start_char': 2141,
#    'end_char': 2145,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b0610>]},
#   {'id': 4,
#    'text': 'apparently',
#    'start_char': 2146,
#    'end_char': 2156,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b0670>]},
#   {'id': 5,
#    'text': 'inevitable',
#    'start_char': 2157,
#    'end_char': 2167,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b06d0>]},
#   {'id': 6,
#    'text': 'exponential',
#    'start_char': 2168,
#    'end_char': 2179,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b0730>]},
#   {'id': 7,
#    'text': 'growth',
#    'start_char': 2180,
#    'end_char': 2186,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22a364b0790>]},
#   {'id': 8,
#    'text': 'only',
#    'start_char': 2187,
#    'end_char': 2191,
#    'coref_chains': []},
#   {'id': 9,
#    'text': 'seems',
#    'start_char': 2192,
#    'end_char': 2197,
#    'coref_chains': []},
#   {'id': 10,
#    'text': 'to',
#    'start_char': 2198,
#    'end_char': 2200,
#    'coref_chains': []},
#   {'id': 11,
#    'text': 'be',
#    'start_char': 2201,
#    'end_char': 2203,
#    'coref_chains': []},
#   {'id': 12,
#    'text': 'so',
#    'start_char': 2204,
#    'end_char': 2206,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 13,
#    'text': '.',
# ...
#    'start_char': 9063,
#    'end_char': 9070,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 18,
#    'text': '’',
#    'start_char': 9070,
#    'end_char': 9071,
#    'coref_chains': []},
#   {'id': 19,
#    'text': 'in',
#    'start_char': 9072,
#    'end_char': 9074,
#    'coref_chains': []},
#   {'id': 20,
#    'text': 'the',
#    'start_char': 9075,
#    'end_char': 9078,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3da7c8b0>]},
#   {'id': 21,
#    'text': 'title',
#    'start_char': 9079,
#    'end_char': 9084,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3da7c910>],
#    'misc': 'SpaceAfter=No'},
#   {'id': 22,
#    'text': ')',
#    'start_char': 9084,
#    'end_char': 9085,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 23,
#    'text': ',',
#    'start_char': 9085,
#    'end_char': 9086,
#    'coref_chains': []},
#   {'id': 24,
#    'text': 'it',
#    'start_char': 9087,
#    'end_char': 9089,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3da7c3d0>]},
#   {'id': 25,
#    'text': 'can',
#    'start_char': 9090,
#    'end_char': 9093,
#    'coref_chains': []},
#   {'id': 26,
#    'text': 'predict',
#    'start_char': 9094,
#    'end_char': 9101,
#    'coref_chains': []},
#   {'id': 27,
#    'text': 'values',
#    'start_char': 9102,
#    'end_char': 9108,
#    'coref_chains': []},
#   {'id': 28,
#    'text': 'up',
#    'start_char': 9109,
#    'end_char': 9111,
#    'coref_chains': []},
#   {'id': 29,
#    'text': 'to',
#    'start_char': 9112,
#    'end_char': 9114,
#    'coref_chains': []},
#   {'id': 30,
#    'text': 'the',
#    'start_char': 9115,
#    'end_char': 9118,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3da7cb50>]},
#   {'id': 31,
#    'text': 'horizon',
#    'start_char': 9119,
#    'end_char': 9126,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3da7cbb0>]},
#   {'id': 32,
#    'text': 'of',
#    'start_char': 9127,
#    'end_char': 9129,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3da7cc10>]},
#   {'id': 33,
#    'text': 'predictability',
#    'start_char': 9130,
#    'end_char': 9144,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3da7cc70>]},
#   {'id': 34,
#    'text': 'and',
#    'start_char': 9145,
#    'end_char': 9148,
#    'coref_chains': []},
#   {'id': 35,
#    'text': 'sometimes',
#    'start_char': 9149,
#    'end_char': 9158,
#    'coref_chains': []},
#   {'id': 36,
#    'text': 'even',
#    'start_char': 9159,
#    'end_char': 9163,
#    'coref_chains': []},
#   {'id': 37,
#    'text': 'further',
#    'start_char': 9164,
#    'end_char': 9171,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 38,
#    'text': '.',
#    'start_char': 9171,
#    'end_char': 9172,
#    'coref_chains': []}],
#  [{'id': 1,
#    'text': 'This',
#    'start_char': 9173,
#    'end_char': 9177,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3da96df0>]},
#   {'id': 2,
#    'text': 'paper',
#    'start_char': 9178,
#    'end_char': 9183,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3da96e50>]},
#   {'id': 3,
#    'text': 'presents',
#    'start_char': 9184,
#    'end_char': 9192,
#    'coref_chains': []},
#   {'id': 4,
#    'text': 'several',
#    'start_char': 9193,
#    'end_char': 9200,
#    'coref_chains': []},
#   {'id': 5,
#    'text': 'methods',
#    'start_char': 9201,
#    'end_char': 9208,
#    'coref_chains': []},
#   {'id': 6,
#    'text': 'of',
#    'start_char': 9209,
#    'end_char': 9211,
#    'coref_chains': []},
#   {'id': 7,
#    'text': 'identifying',
#    'start_char': 9212,
#    'end_char': 9223,
#    'coref_chains': []},
#   {'id': 8,
#    'text': 'unpredictable',
#    'start_char': 9224,
#    'end_char': 9237,
#    'coref_chains': []},
#   {'id': 9,
#    'text': 'points',
#    'start_char': 9238,
#    'end_char': 9244,
#    'coref_chains': []},
#   {'id': 10,
#    'text': 'and',
#    'start_char': 9245,
#    'end_char': 9248,
#    'coref_chains': []},
#   {'id': 11,
#    'text': 'corresponding',
#    'start_char': 9249,
#    'end_char': 9262,
#    'coref_chains': []},
#   {'id': 12,
#    'text': 'strategies',
#    'start_char': 9263,
#    'end_char': 9273,
#    'coref_chains': []},
#   {'id': 13,
#    'text': 'for',
#    'start_char': 9274,
#    'end_char': 9277,
#    'coref_chains': []},
#   {'id': 14,
#    'text': 'the',
#    'start_char': 9278,
#    'end_char': 9281,
#    'coref_chains': []},
#   {'id': 15,
#    'text': 'multi-step',
#    'start_char': 9282,
#    'end_char': 9292,
#    'coref_chains': []},
#   {'id': 16,
#    'text': 'ahead',
#    'start_char': 9293,
#    'end_char': 9298,
#    'coref_chains': []},
#   {'id': 17,
#    'text': 'prediction',
#    'start_char': 9299,
#    'end_char': 9309,
#    'coref_chains': []},
#   {'id': 18,
#    'text': 'as',
#    'start_char': 9310,
#    'end_char': 9312,
#    'coref_chains': []},
#   {'id': 19,
#    'text': 'well',
#    'start_char': 9313,
#    'end_char': 9317,
#    'coref_chains': []},
#   {'id': 20,
#    'text': 'as',
#    'start_char': 9318,
#    'end_char': 9320,
#    'coref_chains': []},
#   {'id': 21,
#    'text': 'demonstrates',
#    'start_char': 9321,
#    'end_char': 9333,
#    'coref_chains': []},
#   {'id': 22,
#    'text': 'partial',
#    'start_char': 9334,
#    'end_char': 9341,
#    'coref_chains': []},
#   {'id': 23,
#    'text': 'predictions',
#    'start_char': 9342,
#    'end_char': 9353,
#    'coref_chains': []},
#   {'id': 24,
#    'text': 'beyond',
#    'start_char': 9354,
#    'end_char': 9360,
#    'coref_chains': []},
#   {'id': 25,
#    'text': 'the',
#    'start_char': 9361,
#    'end_char': 9364,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3da7ccd0>]},
#   {'id': 26,
#    'text': 'horizon',
#    'start_char': 9365,
#    'end_char': 9372,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3da7cd30>]},
#   {'id': 27,
#    'text': 'of',
#    'start_char': 9373,
#    'end_char': 9375,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3da7cdf0>]},
#   {'id': 28,
#    'text': 'predictability',
#    'start_char': 9376,
#    'end_char': 9390,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3da7ce50>]},
#   {'id': 29,
#    'text': 'for',
#    'start_char': 9391,
#    'end_char': 9394,
#    'coref_chains': []},
#   {'id': 30,
#    'text': 'the',
#    'start_char': 9395,
#    'end_char': 9398,
#    'coref_chains': []},
#   {'id': 31,
#    'text': 'benchmark',
#    'start_char': 9399,
#    'end_char': 9408,
#    'coref_chains': []},
#   {'id': 32,
#    'text': 'and',
#    'start_char': 9409,
#    'end_char': 9412,
#    'coref_chains': []},
#   {'id': 33,
#    'text': 'real',
#    'start_char': 9413,
#    'end_char': 9417,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 34,
#    'text': '-',
#    'start_char': 9417,
#    'end_char': 9418,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 35,
#    'text': 'world',
#    'start_char': 9418,
#    'end_char': 9423,
#    'coref_chains': []},
#   {'id': 36,
#    'text': 'time',
#    'start_char': 9424,
#    'end_char': 9428,
#    'coref_chains': []},
#   {'id': 37,
#    'text': 'series',
#    'start_char': 9429,
#    'end_char': 9435,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 38,
#    'text': '.',
#    'start_char': 9435,
#    'end_char': 9436,
#    'coref_chains': [],
#    'misc': 'SpacesAfter=\\n'}],
#  [{'id': 1,
#    'text': 'The',
#    'start_char': 9437,
#    'end_char': 9440,
#    'coref_chains': []},
#   {'id': 2,
#    'text': 'rest',
#    'start_char': 9441,
#    'end_char': 9445,
#    'coref_chains': []},
#   {'id': 3,
#    'text': 'of',
#    'start_char': 9446,
#    'end_char': 9448,
#    'coref_chains': []},
#   {'id': 4,
#    'text': 'the',
#    'start_char': 9449,
#    'end_char': 9452,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3da96f10>]},
#   {'id': 5,
#    'text': 'paper',
#    'start_char': 9453,
#    'end_char': 9458,
#    'coref_chains': [<stanza.models.coref.coref_chain.CorefAttachment at 0x22c3da96f70>]},
#   {'id': 6,
#    'text': 'is',
#    'start_char': 9459,
#    'end_char': 9461,
#    'coref_chains': []},
#   {'id': 7,
#    'text': 'organized',
#    'start_char': 9462,
#    'end_char': 9471,
#    'coref_chains': []},
#   {'id': 8,
#    'text': 'as',
#    'start_char': 9472,
#    'end_char': 9474,
#    'coref_chains': []},
#   {'id': 9,
#    'text': 'follows',
#    'start_char': 9475,
#    'end_char': 9482,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 10,
#    'text': '.',
#    'start_char': 9482,
#    'end_char': 9483,
#    'coref_chains': []}],
#  [{'id': 1,
#    'text': 'The',
#    'start_char': 9484,
#    'end_char': 9487,
#    'coref_chains': []},
#   {'id': 2,
#    'text': 'next',
#    'start_char': 9488,
#    'end_char': 9492,
#    'coref_chains': []},
#   {'id': 3,
#    'text': 'section',
#    'start_char': 9493,
#    'end_char': 9500,
#    'coref_chains': []},
#   {'id': 4,
#    'text': 'reviews',
#    'start_char': 9501,
#    'end_char': 9508,
#    'coref_chains': []},
#   {'id': 5,
#    'text': 'recent',
#    'start_char': 9509,
#    'end_char': 9515,
#    'coref_chains': []},
#   {'id': 6,
#    'text': 'advances',
#    'start_char': 9516,
#    'end_char': 9524,
#    'coref_chains': []},
#   {'id': 7,
#    'text': 'in',
#    'start_char': 9525,
#    'end_char': 9527,
#    'coref_chains': []},
#   {'id': 8,
#    'text': 'the',
#    'start_char': 9528,
#    'end_char': 9531,
#    'coref_chains': []},
#   {'id': 9,
#    'text': 'field',
#    'start_char': 9532,
#    'end_char': 9537,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 10,
#    'text': ';',
#    'start_char': 9537,
#    'end_char': 9538,
#    'coref_chains': []},
#   {'id': 11,
#    'text': 'the',
#    'start_char': 9539,
#    'end_char': 9542,
#    'coref_chains': []},
#   {'id': 12,
#    'text': 'third',
#    'start_char': 9543,
#    'end_char': 9548,
#    'coref_chains': []},
#   {'id': 13,
#    'text': 'section',
#    'start_char': 9549,
#    'end_char': 9556,
#    'coref_chains': []},
#   {'id': 14,
#    'text': 'formally',
#    'start_char': 9557,
#    'end_char': 9565,
#    'coref_chains': []},
#   {'id': 15,
#    'text': 'states',
#    'start_char': 9566,
#    'end_char': 9572,
#    'coref_chains': []},
#   {'id': 16,
#    'text': 'the',
#    'start_char': 9573,
#    'end_char': 9576,
#    'coref_chains': []},
#   {'id': 17,
#    'text': 'problems',
#    'start_char': 9577,
#    'end_char': 9585,
#    'coref_chains': []},
#   {'id': 18,
#    'text': 'under',
#    'start_char': 9586,
#    'end_char': 9591,
#    'coref_chains': []},
#   {'id': 19,
#    'text': 'study',
#    'start_char': 9592,
#    'end_char': 9597,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 20,
#    'text': ';',
#    'start_char': 9597,
#    'end_char': 9598,
#    'coref_chains': []},
#   {'id': 21,
#    'text': 'the',
#    'start_char': 9599,
#    'end_char': 9602,
#    'coref_chains': []},
#   {'id': 22,
#    'text': 'fourth',
#    'start_char': 9603,
#    'end_char': 9609,
#    'coref_chains': []},
#   {'id': 23,
#    'text': 'outlines',
#    'start_char': 9610,
#    'end_char': 9618,
#    'coref_chains': []},
#   {'id': 24,
#    'text': 'clustering',
#    'start_char': 9619,
#    'end_char': 9629,
#    'coref_chains': []},
#   {'id': 25,
#    'text': 'method',
#    'start_char': 9630,
#    'end_char': 9636,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 26,
#    'text': ',',
#    'start_char': 9636,
#    'end_char': 9637,
#    'coref_chains': []},
#   {'id': 27,
#    'text': 'and',
#    'start_char': 9638,
#    'end_char': 9641,
#    'coref_chains': []},
#   {'id': 28,
#    'text': 'methods',
#    'start_char': 9642,
#    'end_char': 9649,
#    'coref_chains': []},
#   {'id': 29,
#    'text': 'employed',
#    'start_char': 9650,
#    'end_char': 9658,
#    'coref_chains': []},
#   {'id': 30,
#    'text': 'to',
#    'start_char': 9659,
#    'end_char': 9661,
#    'coref_chains': []},
#   {'id': 31,
#    'text': 'obtain',
#    'start_char': 9662,
#    'end_char': 9668,
#    'coref_chains': []},
#   {'id': 32,
#    'text': 'predictions',
#    'start_char': 9669,
#    'end_char': 9680,
#    'coref_chains': []},
#   {'id': 33,
#    'text': 'and',
#    'start_char': 9681,
#    'end_char': 9684,
#    'coref_chains': []},
#   {'id': 34,
#    'text': 'also',
#    'start_char': 9685,
#    'end_char': 9689,
#    'coref_chains': []},
#   {'id': 35,
#    'text': 'identify',
#    'start_char': 9690,
#    'end_char': 9698,
#    'coref_chains': []},
#   {'id': 36,
#    'text': 'non-predictable',
#    'start_char': 9699,
#    'end_char': 9714,
#    'coref_chains': []},
#   {'id': 37,
#    'text': 'points',
#    'start_char': 9715,
#    'end_char': 9721,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 38,
#    'text': ';',
#    'start_char': 9721,
#    'end_char': 9722,
#    'coref_chains': []},
#   {'id': 39,
#    'text': 'the',
#    'start_char': 9723,
#    'end_char': 9726,
#    'coref_chains': []},
#   {'id': 40,
#    'text': 'fifth',
#    'start_char': 9727,
#    'end_char': 9732,
#    'coref_chains': []},
#   {'id': 41,
#    'text': 'section',
#    'start_char': 9733,
#    'end_char': 9740,
#    'coref_chains': []},
#   {'id': 42,
#    'text': 'provides',
#    'start_char': 9741,
#    'end_char': 9749,
#    'coref_chains': []},
#   {'id': 43,
#    'text': 'the',
#    'start_char': 9750,
#    'end_char': 9753,
#    'coref_chains': []},
#   {'id': 44,
#    'text': 'prediction',
#    'start_char': 9754,
#    'end_char': 9764,
#    'coref_chains': []},
#   {'id': 45,
#    'text': 'results',
#    'start_char': 9765,
#    'end_char': 9772,
#    'coref_chains': []},
#   {'id': 46,
#    'text': 'for',
#    'start_char': 9773,
#    'end_char': 9776,
#    'coref_chains': []},
#   {'id': 47,
#    'text': 'a',
#    'start_char': 9777,
#    'end_char': 9778,
#    'coref_chains': []},
#   {'id': 48,
#    'text': 'time',
#    'start_char': 9779,
#    'end_char': 9783,
#    'coref_chains': []},
#   {'id': 49,
#    'text': 'series',
#    'start_char': 9784,
#    'end_char': 9790,
#    'coref_chains': []},
#   {'id': 50,
#    'text': 'generated',
#    'start_char': 9791,
#    'end_char': 9800,
#    'coref_chains': []},
#   {'id': 51,
#    'text': 'by',
#    'start_char': 9801,
#    'end_char': 9803,
#    'coref_chains': []},
#   {'id': 52,
#    'text': 'the',
#    'start_char': 9804,
#    'end_char': 9807,
#    'coref_chains': []},
#   {'id': 53,
#    'text': 'Lorenz',
#    'start_char': 9808,
#    'end_char': 9814,
#    'coref_chains': []},
#   {'id': 54,
#    'text': 'system',
#    'start_char': 9815,
#    'end_char': 9821,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 55,
#    'text': ',',
#    'start_char': 9821,
#    'end_char': 9822,
#    'coref_chains': []},
#   {'id': 56,
#    'text': 'and',
#    'start_char': 9823,
#    'end_char': 9826,
#    'coref_chains': []},
#   {'id': 57,
#    'text': 'a',
#    'start_char': 9827,
#    'end_char': 9828,
#    'coref_chains': []},
#   {'id': 58,
#    'text': 'time',
#    'start_char': 9829,
#    'end_char': 9833,
#    'coref_chains': []},
#   {'id': 59,
#    'text': 'series',
#    'start_char': 9834,
#    'end_char': 9840,
#    'coref_chains': []},
#   {'id': 60,
#    'text': 'of',
#    'start_char': 9841,
#    'end_char': 9843,
#    'coref_chains': []},
#   {'id': 61,
#    'text': 'hourly',
#    'start_char': 9844,
#    'end_char': 9850,
#    'coref_chains': []},
#   {'id': 62,
#    'text': 'load',
#    'start_char': 9851,
#    'end_char': 9855,
#    'coref_chains': []},
#   {'id': 63,
#    'text': 'values',
#    'start_char': 9856,
#    'end_char': 9862,
#    'coref_chains': []},
#   {'id': 64,
#    'text': 'in',
#    'start_char': 9863,
#    'end_char': 9865,
#    'coref_chains': []},
#   {'id': 65,
#    'text': 'Germany',
#    'start_char': 9866,
#    'end_char': 9873,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 66,
#    'text': '.',
#    'start_char': 9873,
#    'end_char': 9874,
#    'coref_chains': []}],
#  [{'id': 1,
#    'text': 'Finally',
#    'start_char': 9875,
#    'end_char': 9882,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 2,
#    'text': ',',
#    'start_char': 9882,
#    'end_char': 9883,
#    'coref_chains': []},
#   {'id': 3,
#    'text': 'the',
#    'start_char': 9884,
#    'end_char': 9887,
#    'coref_chains': []},
#   {'id': 4,
#    'text': 'last',
#    'start_char': 9888,
#    'end_char': 9892,
#    'coref_chains': []},
#   {'id': 5,
#    'text': 'section',
#    'start_char': 9893,
#    'end_char': 9900,
#    'coref_chains': []},
#   {'id': 6,
#    'text': 'presents',
#    'start_char': 9901,
#    'end_char': 9909,
#    'coref_chains': []},
#   {'id': 7,
#    'text': 'conclusions',
#    'start_char': 9910,
#    'end_char': 9921,
#    'coref_chains': [],
#    'misc': 'SpaceAfter=No'},
#   {'id': 8,
#    'text': '.',
#    'start_char': 9921,
#    'end_char': 9922,
#    'coref_chains': [],
#    'misc': 'SpacesAfter=\\n\\n'}]]

# %%
resd = {}
for a in dicts:
    for d in a:
        try:
            if d['coref_chains']:
                if d['coref_chains'][0].to_json()['representative_text'] in resd:
                    resd[d['coref_chains'][0].to_json()['representative_text']].append([d['text'], d['start_char'], d['end_char']])
                else:
                    resd[d['coref_chains'][0].to_json()['representative_text']] = [[d['text'], d['start_char'], d['end_char']]]
        except Exception as e:
            continue

# %%
resd
# Out:
# {'have': [['have', 43, 47], ['This', 71, 75]],
#  'the algorithms for a single - step - ahead prediction ( Aghabozorgi et al. , 2015 )': [['the',
#    211,
#    214],
#   ['algorithms', 215, 225],
#   ['for', 226, 229],
#   ['a', 230, 231],
#   ['single', 232, 238],
#   ['-', 238, 239],
#   ['step', 239, 243],
#   ['-', 243, 244],
#   ['ahead', 244, 249],
#   ['prediction', 250, 260],
#   ['(', 261, 262],
#   ['Aghabozorgi', 262, 273],
#   ['et', 274, 276],
#   ['al.', 277, 280],
#   [',', 280, 281],
#   ['2015', 282, 286],
#   [')', 286, 287],
#   ['their', 322, 327]],
#  'their counterparts for a multi-step ahead ( MSA ) prediction': [['counterparts',
#    328,
#    340],
#   ['for', 341, 344],
#   ['a', 345, 346],
#   ['multi-step', 347, 357],
#   ['ahead', 358, 363],
#   ['(', 364, 365],
#   ['MSA', 365, 368],
#   [')', 368, 369],
#   ['prediction', 370, 380],
#   ['their', 394, 399]],
#  'this fact': [['are', 381, 384], ['this', 427, 431], ['fact', 432, 436]],
#  'an exponential growth of an average prediction error with a prediction horizon , that is the number of steps ahead to be predicted': [['an',
#    440,
#    442],
#   ['exponential', 443, 454],
#   ['growth', 455, 461],
#   ['of', 462, 464],
#   ['an', 465, 467],
#   ['average', 468, 475],
#   ['prediction', 476, 486],
#   ['error', 487, 492],
#   ['with', 493, 497],
#   ['a', 498, 499],
#   ['prediction', 500, 510],
#   ['horizon', 511, 518],
#   [',', 518, 519],
#   ['that', 520, 524],
#   ['is', 525, 527],
#   ['the', 528, 531],
#   ['number', 532, 538],
#   ['of', 539, 541],
#   ['steps', 542, 547],
#   ['ahead', 548, 553],
#   ['to', 554, 556],
#   ['be', 557, 559],
#   ['predicted', 560, 569],
#   ['This', 572, 576],
#   ['exponential', 577, 588],
#   ['growth', 589, 595],
#   ['the', 1182, 1185],
#   ['exponential', 1186, 1197],
#   ['growth', 1198, 1204],
#   ['mentioned', 1205, 1214],
#   ['above', 1215, 1220],
#   ['this', 2141, 2145],
#   ['apparently', 2146, 2156],
#   ['inevitable', 2157, 2167],
#   ['exponential', 2168, 2179],
#   ['growth', 2180, 2186],
#   ['it', 2358, 2360]],
#  'any initial difference between two neighbouring trajectories': [['any',
#    730,
#    733],
#   ['initial', 734, 741],
#   ['difference', 742, 752],
#   ['between', 753, 760],
#   ['two', 761, 764],
#   ['neighbouring', 765, 777],
#   ['trajectories', 778, 790],
#   ['the', 792, 795],
#   ['difference', 796, 806],
#   ['its', 842, 845]],
#  'Kantz': [['Kantz', 896, 901], ['Kantz', 1277, 1282]],
#  'Kantz & Schreiber': [['&', 902, 903],
#   ['Schreiber', 904, 913],
#   ['&', 1283, 1284],
#   ['Schreiber', 1285, 1294]],
#  '2003': [['2003', 915, 919], ['2003', 1296, 1300]],
#  'Malinetskii & Potapov': [['Malinetskii', 921, 932],
#   ['&', 933, 934],
#   ['Potapov', 935, 942],
#   ['Malinetskii', 1302, 1313],
#   ['&', 1314, 1315],
#   ['Potapov', 1316, 1323]],
#  '2000': [['2000', 944, 948], ['2000', 1325, 1329]],
#  'the point to be predicted itself': [['the', 1539, 1542],
#   ['point', 1543, 1548],
#   ['to', 1549, 1551],
#   ['be', 1552, 1554],
#   ['predicted', 1555, 1564],
#   ['the', 1686, 1689],
#   ['point', 1690, 1695],
#   ['to', 1696, 1698],
#   ['be', 1699, 1701],
#   ['predicted', 1702, 1711],
#   ['itself', 1712, 1718]],
#  'the algorithm': [['the', 2002, 2005],
#   ['algorithm', 2006, 2015],
#   ['its', 2022, 2025]],
#  'a time series': [['a', 2490, 2491],
#   ['time', 2492, 2496],
#   ['series', 2497, 2503],
#   ['a', 2597, 2598],
#   ['series', 2599, 2605],
#   ['the', 2712, 2715],
#   ['time', 2716, 2720],
#   ['series', 2721, 2727]],
#  'a motif': [['a', 2528, 2529],
#   ['motif', 2530, 2535],
#   ['the', 2648, 2651],
#   ['motif', 2652, 2657]],
#  'vectors of non-successive observations of a series': [['vectors',
#    2766,
#    2773],
#   ['of', 2774, 2776],
#   ['non-successive', 2777, 2791],
#   ['observations', 2792, 2804],
#   ['of', 2805, 2807],
#   ['a', 2808, 2809],
#   ['series', 2810, 2816],
#   ['their', 2885, 2890]],
#  'Gromov': [['Gromov', 3196, 3202],
#   ['Gromov', 3320, 3326],
#   ['Gromov', 5254, 5260],
#   ['Gromov', 5301, 5307],
#   ['Gromov', 7518, 7524]],
#  'the concept of non-predictable points ( non- predictables )': [['the',
#    3264,
#    3267],
#   ['concept', 3268, 3275],
#   ['of', 3276, 3278],
#   ['non-predictable', 3279, 3294],
#   ['points', 3295, 3301],
#   ['the', 3654, 3657],
#   ['concept', 3658, 3665],
#   ['of', 3666, 3668],
#   ['non-predictable', 3669, 3684],
#   ['points', 3685, 3691],
#   ['(', 3692, 3693],
#   ['non-', 3693, 3697],
#   ['predictables', 3697, 3709],
#   [')', 3709, 3710]],
#  'an unpredictable point': [['an', 3358, 3360],
#   ['unpredictable', 3361, 3374],
#   ['point', 3375, 3380],
#   ['the', 3523, 3526],
#   ['point', 3527, 3532],
#   ['it', 3601, 3603]],
#  'algorithm': [['algorithm', 4089, 4098],
#   ['it', 4143, 4145],
#   ['it', 4209, 4211]],
#  'a proper predicted value': [['a', 4164, 4165],
#   ['proper', 4166, 4172],
#   ['predicted', 4173, 4182],
#   ['value', 4183, 4188],
#   ['this', 4234, 4238],
#   ['predicted', 4239, 4248],
#   ['value', 4249, 4254]],
#  'traders': [['traders', 4348, 4355], ['they', 4427, 4431]],
#  'each cluster of z-vectors ( by definition , it includes similar sections of a trajectory )': [['each',
#    4612,
#    4616],
#   ['cluster', 4617, 4624],
#   ['of', 4625, 4627],
#   ['z-vectors', 4628, 4637],
#   ['(', 4638, 4639],
#   ['by', 4639, 4641],
#   ['definition', 4642, 4652],
#   [',', 4652, 4653],
#   ['it', 4654, 4656],
#   ['includes', 4657, 4665],
#   ['similar', 4666, 4673],
#   ['sections', 4674, 4682],
#   ['of', 4683, 4685],
#   ['a', 4686, 4687],
#   ['trajectory', 4688, 4698],
#   [')', 4698, 4699]],
#  'an invariant measure': [['an', 4796, 4798],
#   ['invariant', 4799, 4808],
#   ['measure', 4809, 4816],
#   ['the', 4933, 4936],
#   ['invariant', 4937, 4946],
#   ['measure', 4947, 4954]],
#  'these ( non-successive ) observations': [['observations', 5554, 5566],
#   ['in', 5567, 5569],
#   ['a', 5570, 5571],
#   ['series', 5572, 5578],
#   ['these', 5590, 5595],
#   ['(', 5596, 5597],
#   ['non-successive', 5597, 5611],
#   [')', 5611, 5612],
#   ['observations', 5613, 5625]],
#  'the motifs': [['motifs', 5948, 5954],
#   ['the', 5963, 5966],
#   ['motifs', 5967, 5973]],
#  'the time series at hand': [['the', 6012, 6015],
#   ['time', 6016, 6020],
#   ['series', 6021, 6027],
#   ['at', 6028, 6030],
#   ['hand', 6031, 6035],
#   ['the', 6246, 6249],
#   ['series', 6250, 6256]],
#  'a ‘ comb ’ with teeth where tooth is ‘ broken ’ and the distances between the remaining teeth correspond to some pattern': [['a',
#    6103,
#    6104],
#   ['‘', 6105, 6106],
#   ['comb', 6106, 6110],
#   ['’', 6110, 6111],
#   ['with', 6112, 6116],
#   ['teeth', 6118, 6123],
#   ['where', 6124, 6129],
#   ['tooth', 6130, 6135],
#   ['is', 6137, 6139],
#   ['‘', 6140, 6141],
#   ['broken', 6141, 6147],
#   ['’', 6147, 6148],
#   ['and', 6149, 6152],
#   ['the', 6153, 6156],
#   ['distances', 6157, 6166],
#   ['between', 6167, 6174],
#   ['the', 6175, 6178],
#   ['remaining', 6179, 6188],
#   ['teeth', 6190, 6195],
#   ['correspond', 6196, 6206],
#   ['to', 6207, 6209],
#   ['some', 6210, 6214],
#   ['pattern', 6215, 6222],
#   ['the', 6231, 6234],
#   ['comb', 6235, 6239],
#   ['the', 6340, 6343],
#   ['comb', 6344, 6348]],
#  'a sliding comb with the majority of its teeth broken off': [['a',
#    6441,
#    6442],
#   ['sliding', 6443, 6450],
#   ['comb', 6451, 6455],
#   ['with', 6456, 6460],
#   ['the', 6461, 6464],
#   ['majority', 6465, 6473],
#   ['of', 6474, 6476],
#   ['its', 6477, 6480],
#   ['teeth', 6481, 6486],
#   ['broken', 6487, 6493],
#   ['off', 6494, 6497]],
#  'the number of possible predicted values at each point': [['the', 6697, 6700],
#   ['number', 6701, 6707],
#   ['of', 6708, 6710],
#   ['possible', 6711, 6719],
#   ['predicted', 6720, 6729],
#   ['values', 6730, 6736],
#   ['at', 6737, 6739],
#   ['each', 6740, 6744],
#   ['point', 6745, 6750],
#   ['they', 6761, 6765]],
#  'are': [['are', 6766, 6769], ['This', 6808, 6812]],
#  'a set of possible prediction values': [['a', 6920, 6921],
#   ['set', 6922, 6925],
#   ['of', 6926, 6928],
#   ['possible', 6929, 6937],
#   ['prediction', 6938, 6948],
#   ['values', 6949, 6955],
#   ['them', 6984, 6988]],
#  'our': [['our', 7498, 7501], ['we', 7544, 7546]],
#  'a point': [['a', 7603, 7604], ['point', 7605, 7610], ['it', 7690, 7692]],
#  'the present paper': [['the', 7698, 7701],
#   ['present', 7702, 7709],
#   ['paper', 7710, 7715],
#   ['This', 9173, 9177],
#   ['paper', 9178, 9183],
#   ['the', 9449, 9452],
#   ['paper', 9453, 9458]],
#  'employ': [['employ', 7720, 7726], ['this', 7770, 7774]],
#  'the proposed algorithm': [['the', 7807, 7810],
#   ['proposed', 7811, 7819],
#   ['algorithm', 7820, 7829],
#   ['the', 8803, 8806],
#   ['algorithm', 8807, 8816],
#   ['it', 8899, 8901],
#   ['the', 8991, 8994],
#   ['algorithm', 8995, 9004],
#   ['it', 9087, 9089]],
#  'the iterative strategy': [['the', 8236, 8239],
#   ['iterative', 8240, 8249],
#   ['strategy', 8250, 8258],
#   ['its', 8270, 8273]],
#  'predicts': [['predicts', 8350, 8358], ['This', 8492, 8496]],
#  'unpredictable points': [['unpredictable', 8433, 8446],
#   ['points', 8447, 8453],
#   ['them', 8486, 8490]],
#  'the title': [['the', 8887, 8890],
#   ['title', 8891, 8896],
#   ['the', 9075, 9078],
#   ['title', 9079, 9084]],
#  'the horizon of predictability': [['the', 8927, 8930],
#   ['horizon', 8931, 8938],
#   ['of', 8939, 8941],
#   ['predictability', 8942, 8956],
#   ['the', 9115, 9118],
#   ['horizon', 9119, 9126],
#   ['of', 9127, 9129],
#   ['predictability', 9130, 9144],
#   ['the', 9361, 9364],
#   ['horizon', 9365, 9372],
#   ['of', 9373, 9375],
#   ['predictability', 9376, 9390]]}

# %%
# мердж последовательных
for antecedent in resd:
    for i in range(0,len(resd[antecedent])-1):
        if resd[antecedent][i+1][1] - resd[antecedent][i][2] <= 1:
            resd[antecedent][i+1][1] = resd[antecedent][i][1]
            
for antecedent in resd:
    resa = {idx[1]: [] for idx in resd[antecedent]}
    resmax = {idx[1]: [] for idx in resd[antecedent]}
    
    for idx in resd[antecedent]:
        resa[idx[1]].append(idx[0])
        resmax[idx[1]].append(idx[2])
    
    resd[antecedent] = []
    for ana in [[' '.join(resa[x]), x, max(resmax[x])] for x in resa]:
        if antecedent != ana[0]:
            resd[antecedent].append(ana)
# Out:
# True have ['have', 43, 47]
# True have ['This', 71, 75]
# True the algorithms for a single - step - ahead prediction ( Aghabozorgi et al. , 2015 ) ['the algorithms for a single - step - ahead prediction ( Aghabozorgi et al. , 2015 )', 211, 287]
# True the algorithms for a single - step - ahead prediction ( Aghabozorgi et al. , 2015 ) ['their', 322, 327]
# True their counterparts for a multi-step ahead ( MSA ) prediction ['counterparts for a multi-step ahead ( MSA ) prediction', 328, 380]
# True their counterparts for a multi-step ahead ( MSA ) prediction ['their', 394, 399]
# True this fact ['are', 381, 384]
# True this fact ['this fact', 427, 436]
# True an exponential growth of an average prediction error with a prediction horizon , that is the number of steps ahead to be predicted ['an exponential growth of an average prediction error with a prediction horizon , that is the number of steps ahead to be predicted', 440, 569]
# True an exponential growth of an average prediction error with a prediction horizon , that is the number of steps ahead to be predicted ['This exponential growth', 572, 595]
# True an exponential growth of an average prediction error with a prediction horizon , that is the number of steps ahead to be predicted ['the exponential growth mentioned above', 1182, 1220]
# True an exponential growth of an average prediction error with a prediction horizon , that is the number of steps ahead to be predicted ['this apparently inevitable exponential growth', 2141, 2186]
# True an exponential growth of an average prediction error with a prediction horizon , that is the number of steps ahead to be predicted ['it', 2358, 2360]
# True any initial difference between two neighbouring trajectories ['any initial difference between two neighbouring trajectories', 730, 790]
# True any initial difference between two neighbouring trajectories ['the difference', 792, 806]
# True any initial difference between two neighbouring trajectories ['its', 842, 845]
# True Kantz ['Kantz', 896, 901]
# True Kantz ['Kantz', 1277, 1282]
# True Kantz & Schreiber ['& Schreiber', 902, 913]
# True Kantz & Schreiber ['& Schreiber', 1283, 1294]
# True 2003 ['2003', 915, 919]
# True 2003 ['2003', 1296, 1300]
# True Malinetskii & Potapov ['Malinetskii & Potapov', 921, 942]
# True Malinetskii & Potapov ['Malinetskii & Potapov', 1302, 1323]
# True 2000 ['2000', 944, 948]
# True 2000 ['2000', 1325, 1329]
# True the point to be predicted itself ['the point to be predicted', 1539, 1564]
# True the point to be predicted itself ['the point to be predicted itself', 1686, 1718]
# True the algorithm ['the algorithm', 2002, 2015]
# True the algorithm ['its', 2022, 2025]
# True a time series ['a time series', 2490, 2503]
# True a time series ['a series', 2597, 2605]
# True a time series ['the time series', 2712, 2727]
# True a motif ['a motif', 2528, 2535]
# True a motif ['the motif', 2648, 2657]
# True vectors of non-successive observations of a series ['vectors of non-successive observations of a series', 2766, 2816]
# True vectors of non-successive observations of a series ['their', 2885, 2890]
# True Gromov ['Gromov', 3196, 3202]
# True Gromov ['Gromov', 3320, 3326]
# True Gromov ['Gromov', 5254, 5260]
# True Gromov ['Gromov', 5301, 5307]
# True Gromov ['Gromov', 7518, 7524]
# True the concept of non-predictable points ( non- predictables ) ['the concept of non-predictable points', 3264, 3301]
# True the concept of non-predictable points ( non- predictables ) ['the concept of non-predictable points ( non- predictables )', 3654, 3710]
# True an unpredictable point ['an unpredictable point', 3358, 3380]
# True an unpredictable point ['the point', 3523, 3532]
# True an unpredictable point ['it', 3601, 3603]
# True algorithm ['algorithm', 4089, 4098]
# True algorithm ['it', 4143, 4145]
# True algorithm ['it', 4209, 4211]
# True a proper predicted value ['a proper predicted value', 4164, 4188]
# True a proper predicted value ['this predicted value', 4234, 4254]
# True traders ['traders', 4348, 4355]
# True traders ['they', 4427, 4431]
# True each cluster of z-vectors ( by definition , it includes similar sections of a trajectory ) ['each cluster of z-vectors ( by definition , it includes similar sections of a trajectory )', 4612, 4699]
# True an invariant measure ['an invariant measure', 4796, 4816]
# True an invariant measure ['the invariant measure', 4933, 4954]
# True these ( non-successive ) observations ['observations in a series', 5554, 5578]
# True these ( non-successive ) observations ['these ( non-successive ) observations', 5590, 5625]
# True the motifs ['motifs', 5948, 5954]
# True the motifs ['the motifs', 5963, 5973]
# True the time series at hand ['the time series at hand', 6012, 6035]
# True the time series at hand ['the series', 6246, 6256]
# True a ‘ comb ’ with teeth where tooth is ‘ broken ’ and the distances between the remaining teeth correspond to some pattern ['a ‘ comb ’ with', 6103, 6116]
# True a ‘ comb ’ with teeth where tooth is ‘ broken ’ and the distances between the remaining teeth correspond to some pattern ['teeth where tooth', 6118, 6135]
# True a ‘ comb ’ with teeth where tooth is ‘ broken ’ and the distances between the remaining teeth correspond to some pattern ['is ‘ broken ’ and the distances between the remaining', 6137, 6188]
# True a ‘ comb ’ with teeth where tooth is ‘ broken ’ and the distances between the remaining teeth correspond to some pattern ['teeth correspond to some pattern', 6190, 6222]
# True a ‘ comb ’ with teeth where tooth is ‘ broken ’ and the distances between the remaining teeth correspond to some pattern ['the comb', 6231, 6239]
# True a ‘ comb ’ with teeth where tooth is ‘ broken ’ and the distances between the remaining teeth correspond to some pattern ['the comb', 6340, 6348]
# True a sliding comb with the majority of its teeth broken off ['a sliding comb with the majority of its teeth broken off', 6441, 6497]
# True the number of possible predicted values at each point ['the number of possible predicted values at each point', 6697, 6750]
# True the number of possible predicted values at each point ['they', 6761, 6765]
# True are ['are', 6766, 6769]
# True are ['This', 6808, 6812]
# True a set of possible prediction values ['a set of possible prediction values', 6920, 6955]
# True a set of possible prediction values ['them', 6984, 6988]
# True our ['our', 7498, 7501]
# True our ['we', 7544, 7546]
# True a point ['a point', 7603, 7610]
# True a point ['it', 7690, 7692]
# True the present paper ['the present paper', 7698, 7715]
# True the present paper ['This paper', 9173, 9183]
# True the present paper ['the paper', 9449, 9458]
# True employ ['employ', 7720, 7726]
# True employ ['this', 7770, 7774]
# True the proposed algorithm ['the proposed algorithm', 7807, 7829]
# True the proposed algorithm ['the algorithm', 8803, 8816]
# True the proposed algorithm ['it', 8899, 8901]
# True the proposed algorithm ['the algorithm', 8991, 9004]
# True the proposed algorithm ['it', 9087, 9089]
# True the iterative strategy ['the iterative strategy', 8236, 8258]
# True the iterative strategy ['its', 8270, 8273]
# True predicts ['predicts', 8350, 8358]
# True predicts ['This', 8492, 8496]
# True unpredictable points ['unpredictable points', 8433, 8453]
# True unpredictable points ['them', 8486, 8490]
# True the title ['the title', 8887, 8896]
# True the title ['the title', 9075, 9084]
# True the horizon of predictability ['the horizon of predictability', 8927, 8956]
# True the horizon of predictability ['the horizon of predictability', 9115, 9144]
# True the horizon of predictability ['the horizon of predictability', 9361, 9390]

# %%
resd
# Out:
# {'have': [['This', 71, 75]],
#  'the algorithms for a single - step - ahead prediction ( Aghabozorgi et al. , 2015 )': [['their',
#    322,
#    327]],
#  'their counterparts for a multi-step ahead ( MSA ) prediction': [['counterparts for a multi-step ahead ( MSA ) prediction',
#    328,
#    380],
#   ['their', 394, 399]],
#  'this fact': [['are', 381, 384]],
#  'an exponential growth of an average prediction error with a prediction horizon , that is the number of steps ahead to be predicted': [['This exponential growth',
#    572,
#    595],
#   ['the exponential growth mentioned above', 1182, 1220],
#   ['this apparently inevitable exponential growth', 2141, 2186],
#   ['it', 2358, 2360]],
#  'any initial difference between two neighbouring trajectories': [['the difference',
#    792,
#    806],
#   ['its', 842, 845]],
#  'Kantz': [],
#  'Kantz & Schreiber': [['& Schreiber', 902, 913], ['& Schreiber', 1283, 1294]],
#  '2003': [],
#  'Malinetskii & Potapov': [],
#  '2000': [],
#  'the point to be predicted itself': [['the point to be predicted',
#    1539,
#    1564]],
#  'the algorithm': [['its', 2022, 2025]],
#  'a time series': [['a series', 2597, 2605], ['the time series', 2712, 2727]],
#  'a motif': [['the motif', 2648, 2657]],
#  'vectors of non-successive observations of a series': [['their', 2885, 2890]],
#  'Gromov': [],
#  'the concept of non-predictable points ( non- predictables )': [['the concept of non-predictable points',
#    3264,
#    3301]],
#  'an unpredictable point': [['the point', 3523, 3532], ['it', 3601, 3603]],
#  'algorithm': [['it', 4143, 4145], ['it', 4209, 4211]],
#  'a proper predicted value': [['this predicted value', 4234, 4254]],
#  'traders': [['they', 4427, 4431]],
#  'each cluster of z-vectors ( by definition , it includes similar sections of a trajectory )': [],
#  'an invariant measure': [['the invariant measure', 4933, 4954]],
#  'these ( non-successive ) observations': [['observations in a series',
#    5554,
#    5578]],
#  'the motifs': [['motifs', 5948, 5954]],
#  'the time series at hand': [['the series', 6246, 6256]],
#  'a ‘ comb ’ with teeth where tooth is ‘ broken ’ and the distances between the remaining teeth correspond to some pattern': [['a ‘ comb ’ with',
#    6103,
#    6116],
#   ['teeth where tooth', 6118, 6135],
#   ['is ‘ broken ’ and the distances between the remaining', 6137, 6188],
#   ['teeth correspond to some pattern', 6190, 6222],
#   ['the comb', 6231, 6239],
#   ['the comb', 6340, 6348]],
#  'a sliding comb with the majority of its teeth broken off': [],
#  'the number of possible predicted values at each point': [['they',
#    6761,
#    6765]],
#  'are': [['This', 6808, 6812]],
#  'a set of possible prediction values': [['them', 6984, 6988]],
#  'our': [['we', 7544, 7546]],
#  'a point': [['it', 7690, 7692]],
#  'the present paper': [['This paper', 9173, 9183], ['the paper', 9449, 9458]],
#  'employ': [['this', 7770, 7774]],
#  'the proposed algorithm': [['the algorithm', 8803, 8816],
#   ['it', 8899, 8901],
#   ['the algorithm', 8991, 9004],
#   ['it', 9087, 9089]],
#  'the iterative strategy': [['its', 8270, 8273]],
#  'predicts': [['This', 8492, 8496]],
#  'unpredictable points': [['them', 8486, 8490]],
#  'the title': [],
#  'the horizon of predictability': []}

# %%
# мердж последовательных
for antecedent in resd:
    for i in range(0,len(resd[antecedent])-1):

# %%
resmax
# Out:
# {8927: [8930, 8938, 8941, 8956],
#  9115: [9118, 9126, 9129, 9144],
#  9361: [9364, 9372, 9375, 9390]}

# %%
# мердж последовательных
resd_new = dict(zip(resd.keys(), [[]]*len(resd.keys())))
for antecedent in resd:
    for i in range(0,len(resd[antecedent])+1):
        if resd[antecedent][i+1][1] - resd[antecedent][i][2] <= 1:
            resd[antecedent][i+1][1] = resd[antecedent][i][1]
    
for antecedent in resd:
    new_pro_forma = [resd[antecedent][0][0],0,0]
    for i in range(1,len(resd[antecedent])):
        if resd[antecedent][i][3] > 1:

# %%
resd_new
# Out:
# {'have': [],
#  'the algorithms for a single - step - ahead prediction ( Aghabozorgi et al. , 2015 )': [],
#  'their counterparts for a multi-step ahead ( MSA ) prediction': [],
#  'this fact': [],
#  'an exponential growth of an average prediction error with a prediction horizon , that is the number of steps ahead to be predicted': [],
#  'any initial difference between two neighbouring trajectories': [],
#  'Kantz': [],
#  'Kantz & Schreiber': [],
#  '2003': [],
#  'Malinetskii & Potapov': [],
#  '2000': [],
#  'the point to be predicted itself': [],
#  'the algorithm': [],
#  'a time series': [],
#  'a motif': [],
#  'vectors of non-successive observations of a series': [],
#  'Gromov': [],
#  'the concept of non-predictable points ( non- predictables )': [],
#  'an unpredictable point': [],
#  'algorithm': [],
#  'a proper predicted value': [],
#  'traders': [],
#  'each cluster of z-vectors ( by definition , it includes similar sections of a trajectory )': [],
#  'an invariant measure': [],
#  'these ( non-successive ) observations': [],
#  'the motifs': [],
#  'the time series at hand': [],
#  'a ‘ comb ’ with teeth where tooth is ‘ broken ’ and the distances between the remaining teeth correspond to some pattern': [],
#  'a sliding comb with the majority of its teeth broken off': [],
#  'the number of possible predicted values at each point': [],
#  'are': [],
#  'a set of possible prediction values': [],
#  'our': [],
#  'a point': [],
#  'the present paper': [],
#  'employ': [],
#  'the proposed algorithm': [],
#  'the iterative strategy': [],
#  'predicts': [],
#  'unpredictable points': [],
#  'the title': [],
#  'the horizon of predictability': []}

# %%
modified_text = text
list_init = list(range(len(modified_text)))

for antecedent in resd:
    for mention in resd[antecedent]:
        if mention[0] not in antecedent:
            extp = f'{mention[0]} (->{antecedent})'
            modified_text = modified_text[:list_init.index(mention[1])] + extp + modified_text[list_init.index(mention[2]):]
            list_init = list_init[:list_init.index(mention[1])] + [-1]*len(extp) + list_init[list_init.index(mention[2]):]

# %%
modified_text
# Out:
# '\nChaotic systems, both social and natural, have a widespread currency. This (->have) may explain a constantly increasing number of prediction algorithms for chaotic time series. It is worth stressing however, that while the algorithms for a single-step-ahead prediction (Aghabozorgi et al., 2015) appear to be amazingly efficient; their (->the algorithms for a single - step - ahead prediction ( Aghabozorgi et al. , 2015 )) counterparts for a multi-step ahead (MSA) prediction are (->this fact) still in their infancy. One may attribute this fact to an exponential growth of an average prediction error with a prediction horizon, that is the number of steps ahead to be predicted. \nThis (->an exponential growth of an average prediction error with a prediction horizon , that is the number of steps ahead to be predicted) exponential growth reflects Lyapunov instability, immanent to any chaotic system. Namely, according to Lyapunov instability definition, however small is any initial difference between two neighbouring trajectories, the (->any initial difference between two neighbouring trajectories) difference grows exponentially with time, and its (->any initial difference between two neighbouring trajectories) exponent equals to the highest Lyapunov exponent (Kantz & Schreiber, 2003; Malinetskii & Potapov, 2000). Laypunov instability also leads to another concept, that of a horizon of predictability (sometimes also referred to as Lyapunov time (Bezruchko & Smirnov, 2010)). For a given observational error  and the maximum prediction error , the exponential growth mentioned (->an exponential growth of an average prediction error with a prediction horizon , that is the number of steps ahead to be predicted) above (->an exponential growth of an average prediction error with a prediction horizon , that is the number of steps ahead to be predicted) satisfies, thereby giving a horizon of predictability  (Kantz & Schreiber, 2003; Malinetskii & Potapov, 2000). In the context of a multi-step ahead prediction, this implies that the smallest difference between true and predicted values in an intermediate point (that is the point between the last observable point and the point to be predicted) – inevitable for any prediction method – triggers exponential error growth in all subsequent intermediate points and in the point to be predicted itself. Therefore, a horizon of predictability is an upper theoretical boundary for the number of steps ahead to be predicted for any prediction algorithm (for given  and ). A horizon of predictability should not be confused with a prediction horizon, which is a mere number of steps ahead the algorithm makes its (->the algorithm) prediction. Usually, a prediction horizon  is essentially lesser than a horizon of predictability : .\nNonetheless, this (->an exponential growth of an average prediction error with a prediction horizon , that is the number of steps ahead to be predicted) apparently (->an exponential growth of an average prediction error with a prediction horizon , that is the number of steps ahead to be predicted) inevitable (->an exponential growth of an average prediction error with a prediction horizon , that is the number of steps ahead to be predicted) exponential growth only seems to be so. Predictive clustering (Blockeel & De Raedt, 1998; Gromov & Borisenko, 2015) furnishes several tools that, applied together, make it possible to avoid it.\nFirst, predictive clustering uses motifs – repeated sequences of data in a series (with some small variations). If a section of a time series resembles first part of a motif ‘closely enough’, it is likely that the subsequent points of a series will be close to the subsequent points of the (->a motif) motif, allowing one to use motifs to predict next points of the (->a time series) time series. Motifs can be obtained by clustering vectors of non-successive observations of a series into z-vectors (irregular embeddings (Small, 2005)) and calculating their (->ve ...

# %%
with open('Article.txt', 'r', encoding="utf8") as f:
    article = f.read()

# %%
print(article)
# Out:
# ﻿
# Prediction After a Horizon of Predictability:
# Non-Predictable Points and Partial Multi-Step Prediction for Chaotic Time Series
#
# Vasilii A. Gromov, Philip S. Baranov, and Alexandr Yu. Tsybakin
# HSE University
# Pokrovskii Boulevard, 11, Moscow, Russian Federation
# Vasilii A. Gromov, stroller@rambler.ru (corresponding author:)
# Philip S. Baranov, pbaranov1306@gmail.com
# Alexandr Yu. Tsybakin, a.tsby@yandex.ru
# Abstract. The paper introduces several novel strategies for multi-step prediction of chaotic time series. Generalized z-vectors (irregular embeddings), comprising non-successive observations, make it possible to obtain a fairly large set of possible predicted values for each point to be predicted. Upon examining such a set, it may possible either to calculate a unified (‘final’) predicted value for a particular point (thus making it a ‘predictable’ point) or not (in which case the point becomes ‘unpredictable’). With non-predictable points, the multi-step prediction process is, in fact, a two-objective problem: on one hand, we aim to minimise the total number of unpredictable points; on the other – we try to minimise the average error among the predictable ones. The main difference between the strategies presented in this paper and their classical counterparts is the concept of ‘unpredictable’ points – i.e., skipping points where the predicted value will clearly be wrong and calculating predictions only for the ‘good’ points. The results of the present research indicate that, for such algorithms, the number of non-predictable points grows exponentially with a prediction horizon; however, an average error for predictable points tends to remain constant and relatively small up to the horizon of predictability and sometimes even farther (for benchmark and real-world time series).
#
# Keywords. Chaotic time series, multi-step prediction, predictive clustering, predictable and non-predictable points, a horizon of predictability.
#
# I. INTRODUCTION
# Chaotic systems, both social and natural, have a widespread currency. This may explain a constantly increasing number of prediction algorithms for chaotic time series. It is worth stressing however, that while the algorithms for a single-step-ahead prediction (Aghabozorgi et al., 2015) appear to be amazingly efficient; their counterparts for a multi-step ahead (MSA) prediction are still in their infancy. One may attribute this fact to an exponential growth of an average prediction error with a prediction horizon, that is the number of steps ahead to be predicted.
# This exponential growth reflects Lyapunov instability, immanent to any chaotic system. Namely, according to Lyapunov instability definition, however small is any initial difference between two neighbouring trajectories, the difference grows exponentially with time, and its exponent equals to the highest Lyapunov exponent (Kantz & Schreiber, 2003; Malinetskii & Potapov, 2000). Laypunov instability also leads to another concept, that of a horizon of predictability (sometimes also referred to as Lyapunov time (Bezruchko & Smirnov, 2010)). For a given observational error  and the maximum prediction error , the exponential growth mentioned above satisfies, thereby giving a horizon of predictability  (Kantz & Schreiber, 2003; Malinetskii & Potapov, 2000). In the context of a multi-step ahead prediction, this implies that the smallest difference between true and predicted values in an intermediate point (that is the point between the last observable point and the point to be predicted) – inevitable for any prediction method – triggers exponential error growth in all subsequent intermediate points and in the point to be predicted itself. Therefore, a horizon of predictability is an upper theoretical boundary for the number of steps ahead to be predicted for any prediction algorithm (for given  and ). A horizon of predictability should not be confused with a prediction horizon, which is a mere number of steps ahead the algorithm makes its prediction. Usually, a prediction horizon  is essentially lesser than a horizon of predictability : .
# Nonetheless, this apparently inevitable exponential growth only seems to be so. Predictive clustering (Blockeel & De Raedt, 1998; Gromov & Borisenko, 2015) furnishes several tools that, applied together, make it possible to avoid it.
# First, predictive clustering uses motifs – repeated sequences of data in a series (with some small variations). If a section of a time series resembles first part of a motif ‘closely enough’, it is likely that the subsequent points of a series will be close to the subsequent points of the motif, allowing one to use motifs to predict next points of the time series. Motifs can be obtained by clustering vectors of non-successive observations of a series into z-vectors (irregular embeddings (Small, 2005)) and calculating their respective centers. It is worth stressing that most available prediction methods attempt to construct a unified, global prediction model, whereas predictive clustering methods, vice versa, build up a set of separate, local prediction models, motifs (cf. global vs. local learning (Ben Taieb et al., 2010; Gromov, 2019)).
# Second, predictive clustering allows one to develop the concept of non-predictable points in a natural way (Gromov & Borisenko, 2015). Initially, an unpredictable point was the fone for which the algorithm failed to find a corresponding motif that would be close enough and based on which the possible value of the point could be estimated (a set of possible predicted values is empty for it. It is worthy to emphasize that if one introduces the concept of non-predictable points (non-predictables), one thereby renders the problem two-objective: one must minimise simultaneously the number of non-predictable points and the average error over predictable ones. In the conventional statement, the first objective is discarded – predictions are made for every single point. Introduction of unpredictable points proved to have a positive effect on the results – it is better for algorithm to skip some points along the way for which it is unable to find a proper predicted value rather than forcing it regardless of whether this predicted value will be accurate or not. This approach is actually quite natural in some areas: for example, traders are not compelled to buy and/or sell at every single moment – instead, they may choose only those moments in time that the algorithm has recognized as predictable.
# In the context of dynamical systems (Kantz & Schreiber, 2003; Malinetskii & Potapov, 2000), each cluster of z-vectors (by definition, it includes similar sections of a trajectory) corresponds to a particular area of a strange attractor. Furthermore, areas with high values of an invariant measure are associated with large clusters (i.e., with frequently observed motifs). Similarly, areas with smaller values of the invariant measure are associated with smaller clusters (i.e., rarely observed motifs). Consequently, as a training set increases – so does the number of clusters, while the number of unpredictable points, as well as the average error of the predictable ones, decrease. A large-scale simulation for the Lorenz series (Gromov, 2019) supports this conclusion.
# Third, Gromov and Borisenko (2015) use generalized z-vectors – vectors comprised of non-successive observations according to certain predefined patterns (irregular embeddings (Small, 2005)). A pattern is defined as a sequence of distances between positions of observations in a series, such that these (non-successive) observations become successive in a generated vector. This concatenated vector generalizes a conventional z-vector (Kantz & Schreiber, 2003; Malinetskii & Potapov, 2000), which corresponds to the pattern  ( times). Figure 1 presents a sample vector constructed according to the pattern   and shows the way z-vectors are clustered into motifs and how the motifs can be used to obtain predictions for the time series at hand. The process of generating a z-vector can be visualized as placing a ‘comb’ with  teeth where tooth  is ‘broken’ and the distances between the remaining  teeth correspond to some pattern. Moving the comb along the series, we, for each position , obtain a vector of observations, to be under the teeth of the comb, . To put it differently, for a given pattern, a conventional sliding window is replaced by a sliding comb with the majority of its teeth broken off. A set of such vectors comprises a sample corresponding to a pattern of    . Each such sample is clustered separately.
# Fourth, due to the fact that the number of patterns can be significant, so can the number of possible predicted values at each point; however, they are not always statistically independent. This makes it possible to design a great deal of various algorithms to determine a unified prediction value for a set of possible prediction values (for instance, by averaging them). It also becomes possible to extend the concept of the unpredictable points: apart from the points that do not have a corresponding motif that would be close enough, we can also consider points for which it is impossible to calculate a unified prediction value based on the set of possible predicted values to be unpredictable as well. An example case of such a point would be a point which set of predicted values consists of two equally sized clusters with different centres. It is worth stressing that in our previous paper (Gromov & Borisenko, 2015) we employed non-predictable points of the first kind only (a point is non-predictable if there are no motifs close enough to make predictions for it). In the present paper, we employ both kinds of non-predictable points – and this appears to make it possible for the proposed algorithm to predict for so many steps ahead.
# It is worth noting that since patterns with a distance between penultimate and ultimate teeth greater than 1, , exist, the fact that a position  is non-predictable does not imply that positions , , etc. would be non-predictable too. This fact is of fundamental importance for multi-step ahead prediction: If one needs to predict a point at a position , one would use the iterative strategy (or rather its modification based on patterns of non-successive observations). Namely, one predicts values for intermediate positions between  and  step by step, identifying unpredictable points along the way and stepping over them. This results in unpredictable sections between predictable positions. We used to refer to the former as a ‘bog’, and to the latter as ‘hillocks’. The entire prediction process is likened to jumping from a hillock to hillock in order to navigate a swamp (or to put it differently – using stepping stones).
# While the algorithm cannot produce a prediction at each point (thus the word ‘partial’ in the title), it can predict values up to the horizon of predictability and sometimes even further. While the algorithm cannot produce a prediction at each point (thus the word ‘partial’ in the title), it can predict values up to the horizon of predictability and sometimes even further. This paper presents several methods of identifying unpredictable points and corresponding strategies for the multi-step ahead prediction as well as demonstrates partial predictions beyond the horizon of predictability for the benchmark and real-world time series.
# The rest of the paper is organized as follows. The next section reviews recent advances in the field; the third section formally states the problems under study; the fourth outlines clustering method, and methods employed to obtain predictions and also identify non-predictable points; the fifth section provides the prediction results for a time series generated by the Lorenz system, and a time series of hourly load values in Germany. Finally, the last section presents conclusions.
#
# II. RELATED WORKS
# Recent papers that concern themselves with chaotic time series prediction are quite numerous (Aghabozorgi et al., 2015; Bao et al., 2014; Ben Taieb et al., 2010; Gromov & Borisenko, 2015; Sangiorgio & Dercole, 2020; Ye & Dai, 2019) but most of them only deal with one-step ahead prediction. At the same time, the number of papers tackling the problem of the multi-step ahead prediction (MSA) is considerably lower. This could be attributed to the exponential growth of the average prediction error with an increasing prediction horizon.
# An MSA prediction algorithm for chaotic time series usually consists of two parts, responsible collectively for the prediction quality. The first is a technique used for a one- or few-step-ahead prediction. The second is a strategy utilized to ‘assemble’ one- or few-step ahead predictions to a multi-step ahead prediction.
# Algorithms used for a one-step-ahead prediction employs concepts of nearly all fields of data mining and machine learning: support vector regression and its modifications (Bao et al., 2014), multilayer perceptron (Chandra et al., 2017; Mirzaee, 2009), cluster centres in predictive clustering (Gromov et al., 2017; Gromov & Konev, 2017; Gromov & Shulga, 2012; Martínez-Álvarez et al., 2011), LSTM neural networks (Sangiorgio & Dercole, 2020), Voronoi regions partitioning (Kurogi et al., 2014), ridge polynomial neural networks (Waheeb & Ghazali, 2016), wavelet neural networks (Guntu et al., 2020; Ong & Zainuddin, 2019), dilated convolution networks (R. Wang et al., 2020), to name just a few. Dilated convolution networks could be viewed as counterparts of patterns of non-successive observations (see below).
# Another factor of fundamental importance is the strategies of MSA prediction. The problem can be solved using two basic strategies – the iterated (recursive) strategy and the direct (Ben Taieb et al., 2012; Cox, 1961) strategy. The iterated one implies that the multi-step ahead prediction process is carried out step-by-step, calculating new predicted values based on the predictions made in the previous steps. The direct strategy aims for getting the results immediately, without calculating predicted values for the intermediate positions. The strategy applies prediction techniques for various prediction horizons, thereby providing multiple predictions for a position to be predicted. Taieb, Sorjamaa, and Bontempi (2010) review different methods based on these two basic strategies. Sangiorgio and Dercole (2020) apply both strategies with multilayer perceptrons and LSTM nets employed as tools to predict for a one step ahead.
# Unfortunately, MSA methods designed in the framework of the aforementioned strategies are, in one way or another, amenable to ‘a curse of an exponential growth,’ discussed above. This gives rise to a number of hybrid strategies aiming to resolve this problem. Ben Taieb et al. (2012), in their brilliant review, compare two basic and three novel strategies (DirRec, MIMO, and DIRMO). DirRec (Direct + Recursive) combines two basic strategies to the effect that it uses the direct approach to predict values, but the number of inputs is enlarged iteratively to include values for just predicted positions. When it comes to the MIMO (Multiple Input Multiple Output) strategy (Universit & Bontempi, 2014), an array of values is produced for the positions between the observed values and a prediction horizon inclusive instead of only a single value corresponding to the prediction horizon. This allows any correlations that the time series in question might have to be stored in the predicted values.
# Chaotic time series prediction methods that rely upon reservoir computing would mark a different approach (Jaeger, 2004; Lu et al., 2017). Lu et al. (2017) indicate that the method demonstrates excellent results for small prediction horizons; however, their performance severely worsens when applied to larger horizons. Nevertheless, a predicted sequence ‘behaves like the measurements from a typical trajectory on the attractor’ and this approach converges quickly (Canaday et al., 2018). DIRMO (DirRec + MIMO) divides the series up to a prediction horizon into blocks and applies MIMO strategy separately to each block. Authors test these five strategies on a reasonably large sample of different time series (NN5 competition), which reflects various irregularities inherent to time series.
# Bao, Xiong, and Hu (2014) compare the efficiency of the iterated, direct, and MIMO strategies by performing a one-step-ahead prediction using a modified support vector regression. According to the authors, the MIMO compares favourably with two other strategies (all other factors being equal).
#  Multiple-task learning can be viewed as a kind of strategy for multi-step ahead prediction. Chandra, Ong, and Goh (2017) propose an algorithm to determine a neural network structure to solve MSA prediction problems; their approach can be considered as a combination of the direct and iterated strategies. Wang et al. (2019) utilize a neural model in order to combine periodic approximations for longer periods and machine learning models for shorter periods. This could be viewed as a separate strategy when dealing with data with a marked periodicity. Ye and Dai (2019) employ multi-task learning for multi-step prediction; it is possible to view multi-task learning as a kind of MSA predicted strategy. Kurogi, Shigematsu, and Ono (2014) make use of an out-of-bag model for selecting models for multi-step prediction. Authors aim at predicting a chaotic series as far as it is possible (the largest possible prediction horizon) while retaining reasonable accuracy. Authors present results for the Lorenz series. The present paper discusses a few novel strategies; the main difference from their classical counterparts is non-predictable points, and consequently, an ability to not account for predictions at intermediate positions that are clearly erroneous (Gromov & Borisenko, 2015).
#
# III. PROBLEM STATEMENT
# The paper considers a  -step-ahead prediction problem for a chaotic time series , . We assume that all transient processes in the system that generate the time series have been completed, and the time series reflects the trajectory movement in the neighbourhood of a strange attractor, however complex it can be. The second assumption is that the series meets Takens’ theorem conditions and, consequently, it is possible analyse the attractor structure using time series observations (Kantz & Schreiber, 2003; Malinetskii & Potapov, 2000).
# A series is divided into two parts:  and , with  being an observable part, used as a training set a prediction model and   being a test set);  , . When the algorithm predicts a value at the  position of the test set, it possesses information about observations from  up to  inclusively, it does not possess information observations about positions .where  is a parameter of the algorithm.
# Predictive-clustering algorithms and a large number of used patterns make it possible to build up a set of possible predicted values  for each position to be predicted.  is the number of possible predicted values found by an algorithm, where  is the th predicted value. A set  is defined as  and is comprised of sets of possible predicted values for the position  itself and for  preceding positions, with  being a parameter of the algorithm. It usually takes values  or . For , the set  consists of the set of possible predicted values for the position  only; for , it consists of sets for the position  itself and for all intermediate positions between the last observable point and the position . We denote an algorithm that builds up sets of possible predicted values  as : .
# The concept of non-predictable points implies that one applies two operators to the set . The first checks whether the position is predictable:
#
#
# (1)
#
# where  for any function .
# The second determines a unified predicted value for a set of possible predicted values, provided the position appears to be predictable:
#
#
# (2)
#
# In these terms, a multi-step ahead prediction problem can be stated as a two-objective optimization problem:
#
# (3)
#
# (4)
# For both functionals, one sums over all observations of a test set. The first functional minimises the number of non-predictable points, while the second one minimizes an average error for the predictable ones. In this paper, authors attempt to solve the two-objective optimization problem (3), (4).
#
# IV. PREDICTION ALGORITHM
# This section describes the proposed prediction algorithm. The first subsection deals with a way to generate samples from the time series according to predefined patterns; the second one talks about the employed clustering techniques. The third, fourth, and fifth provide ways of generating a set of possible predicted values, quality measures of identification of unpredictable points, and techniques of identification of unpredictable points respectively. Each technique in this section is denoted by a label in square brackets (for example, [p]) for ease of reference in the next section – Numerical Results.
# 2.1. Training set
# The series is considered to be normalized. The concept of patterns is used to generate samples. A pattern is defined as an array of distances between positions of observations such that these (non-successive) observations become successive in a sample vector. Thus, each pattern is a -dimensional vector of integers , ; the parameter  dictates the maximum distance between positions of observations that become neighbours in the vector to be generated. Thereby, the quantity  symbolizes a kind of memory depth.  denotes a set of all possible patterns of length . The vector thus concatenated generalizes a conventional z-vector (Kantz & Schreiber, 2003; Malinetskii & Potapov, 2000), which corresponds to the pattern (1, 1, …, 1) ( times).
# For example, let us consider a four-point pattern (2, 3, 4). For this pattern, the two first vectors of a training set would be  and ; the last one vector would then be , where  is the last observable value.
# Conventionally, one used, for predictive clustering, vectors that concatenated successive observations (z-vectors); they proved less efficient (Gromov & Borisenko, 2015) than those based on the vectors concatenated according to various patterns, generalized z-vectors, discussed above. One may attribute this to the fact that vectors of non-successive observations are able to store information about salient observations (minima, maxima, tipping points, and so forth), as well as correlations between them. Figure 2 above shows a pattern superimposed on a time series in order to generate a sample vector.
# It is possible to use either the entire set of all combinatorically possible patterns  for generating training sets or its part consisting of randomly chosen patterns. The patterns should be chosen before simulation starts. A set of used patterns is denoted as , where  is a percentage of patterns used. In particular,  corresponds to the case of all possible patterns being used.
# Training sets are generated independently for each pattern . Motifs may be extracted from each training set by two possible ways. The first one utilizes vectors of a training set as motifs [p] (pointwise); this approach bears a close resemblance to lazy learning (Ben Taieb et al., 2012). The second implies that a sample is clustered, and centres of the clusters are used as the motifs in question [cl] (cluster); except as otherwise noted, the clustering technique is the modified Wishart (please, refer to the next subsection). Despite its drawbacks, the first method compares favourably with the second in terms of required computations.
# We denote a set of motifs corresponding to a pattern ,  as , . The motifs obtained this way can be used only with the respective pattern , which indicates distances between positions in a series, such that values  may occupy. A set of all used motifs is denoted as , .
#
# 2.2. Clustering technique
# As the trajectory of a system moves through the same area of an attractor repeatedly, similar sequences (associated with that area) can be repeatedly encountered in the time series. Revealing and describing such areas, as well as developing simple prediction models for each of them, makes it possible to predict chaotic time series up to a considerable limit (Gromov & Shulga, 2012). The clustering method presented below is employed to collect sequences belonging to the same cluster.
# We employ the Wishart clustering technique (Bock, 1970; Wishart, 1969) as modified by Lapko and Chentsov (Lapko & Chentsov, 2000) to cluster vectors. The method employs graph theory concepts and a non-parametric probability density function estimator of  -nearest neighbours. Some difficulties associated with the application of the algorithm to forecasting problems are discussed in (Gromov & Borisenko, 2015).
# An estimated saliency for a point  is defined as , where  and  are the volume and radius of the minimum hypersphere with its centre at point  containing at least  observations. The method relies upon a similarity relation (proximity) graph , vertices of which correspond to samples and edges defined as .  is a generated subgraph for graph , with a vertex set  and an edge set that comprises all edges from , such that their vertices belong to the set .  is a cluster number (label) for . A cluster  () is said to be a height-significant one (with respect to height value ) if
# Thus, the algorithm consists of the following steps:
#     1. Determine distances  for each sample to its -nearest neighbor and sort the samples in ascending order according to their respective ;
#     2. Set ;
#     3. For each subgraph  the following alternatives are possible:
#         3.1.  If a vertex  is an isolated vertex of , then start a new cluster;
#         3.2.  If a vertex  is connected to vertices of clusters :
#             3.2.1. If all  clusters are completed, then set .
#             3.2.2. Otherwise, determine the number of significant clusters :
#                 3.2.2.1. If  or  , then set , label significant clusters as completed and delete insignificant clusters, setting  for all samples that belong to them.
#                 3.2.2.2. Otherwise, merge clusters  into , setting
#  for the sample itself and for all samples belonging to them.
#     4. Set . If , then go to step 3.
#
# We used the following values: , .
#
# 2.3. Sets of possible predicted values ()
# For a given pattern , , we consider a set of all corresponding motifs  and, using them, builds up a set of possible predicted values  associated with the pattern . Namely, for a given position to be predicted , we compose a vector from time series observations according to the pattern : . All elements of the vector  are assumed to be known – they may be either observed or already predicted values. Then if the Euclidean distance between a vector  and a truncated motif ,  (a truncated motif comprises all elements but the last one,  for ), then the last element of the motif , , is a reasonable estimate of the value to be predicted.
# Respectively, the set  is determined as
# , where  is a small threshold. In turn, a set of possible predicted values for a position  is a union of the sets  over all possible patterns, . The unified predicted value  is calculated as a function of the set of possible predicted values for this position .
# Previously predicted values at intermediate positions  are used as inputs for new iterations of the algorithm until some prediction horizon  is reached. Let us call each iteration a ‘prediction operation’ – a generalized step in the iterated strategy. Once again, it is not necessary to make predictions for all intermediate positions – some may be skipped.
# A repeated application of this procedure produces an algorithm that implements an operator : , which yields a set of possible predicted values for a position  to be predicted. Since the number of patterns is rather large, so the size of the set may be. This makes it possible to design various algorithms to determine a unified predicted value and identify non-predictable points. These algorithms are discussed in greater detail later.
# Apart from sets of possible predicted values, we can also calculate a set of weights , , which characterize comparative significance of possible predicted values . We utilize several alternatives to determine weights, based upon the following ideas:
#
#     1. The first technique relies on the notion of ‘prediction length’ required to obtain a predicted value . The algorithm introduces some error with each run of the prediction operation, therefore making the result less reliable the more times the prediction operation has been performed. Since the distances between the first and last positions for various patterns may differ significantly for large , the number of prediction operations carried out to obtain various  values may significantly differ as well. To calculate this quantity, we use the following recurrence relation. We assign unity weights  to observed values; then, if  a possible predicted value  is obtained using a pattern  and the values   (observed or predicted) are used as inputs for this prediction operation  have weights , then one calculates the weight of these value as an average of these weights times a step-down factor :
#
# (5)
#
# We assign average weight of all possible predicted values that take part in its calculation to the unified predicted value. Thus, the step-down factor  ensures that values calculated with a larger number of prediction operations receive smaller weights. In the simulation,  usually takes up a value of  [wl] (weighted sum, length).
#     2. The second technique suggests that a weight  is inversely proportional to the distance between observed values and the centre of the cluster chosen to make the prediction:
#
#
# (6)
#
# , where  is a small parameter used as a threshold for building up a set of possible predicted values. In the simulation,  usually equals  (for a normalized series) [wd] (weighted sum, distance).
#     3. The third approach suggests that a weight  is a product of weights of the first and second approaches [w] (weighted sum, combined).
#
# 2.4. A unified predicted value ( (1))
# The basic dichotomy for algorithms when determining a unified predicted value is whether  or . If , the unified predicted value is determined using a set of possible predicted values associated with the current position,  [S] (set). If , it also employs the sets associated with preceding positions [T] (trajectory).
# For the case of , several techniques to determine the unified predicted value for a set of possible predicted values  are possible:
#     • Calculating an average value:  [av] (an average)
#     • Calculating a weighted average value:  [wl, wd, or w] (please, see above).
#     • Clustering a set  in order to select the largest cluster :
# , , , . The modified Wishart (Wishart, 1969) and DBSCAN (Maronna, 2016) are employed. The latter gives a good account of itself for one-dimensional data, that is fully applicable to a set . Both algorithms do not require a priori information about the true number of clusters. The unified predicted value is calculated as  [cm] (maximum cluster).
#     4. This technique is similar to the previous one with one exception: we cluster only those elements of , which weights are greater than some threshold . Alternatively, one may discard  percent of observations with the least weights, regardless of the weights absolute values [cw] (a maximum cluster, weighted).
#     5. The two last techniques can be readily extended to the fuzzy sets. Normalized weights could be viewed, quite naturally, as values of a membership function to belong to a set of possible predicted values. A clustering algorithm should be replaced by some algorithm that can cluster fuzzy data [fs] (a fuzzy set).
#     6. Roulette wheel. Similarly to the previous techniques, we cluster a set of possible predicted values, but probabilistically choose the cluster which centre will be used as the unified predicted value. Probability for a cluster to be chosen is directly proportional to the number of elements it contains or to the normalized sum of weights associated with its elements [rw] (a roulette wheel).
#     7. Most frequent value. We divide a range of values of the series in question, into disjoint intervals of equal lengths : , , . An average value calculated over the elements of the most ‘populated’ interval, , is the unified predicted value [mf] (the most frequent).
#     8. Randomly perturbed most frequent value. This approach is essentially the same as the previous one, with the exception of adding a normally distributed noise to the average value:  , where  is a normally distributed random variable with zero mean and variance  [mp] (the most frequent, perturbed).
#
# When , we utilize the concept of a ‘possible predicted trajectory.’ A possible predicted trajectory is defined as a sequence of possible predicted values at positions (not necessarily successive) preceding a prediction horizon and at the prediction horizon itself. In the framework of this approach, instead of producing sequence of sets of possible predicted values, the prediction method produces a set of possible trajectories that end in a prediction horizon. For some methods, the trajectory is built by adding a random component at each position, thus making the maximum number of trajectories a parameter of the prediction algorithm. For other methods, several values are chosen at each point instead of a single unified prediction value, thereby making a ‘fan’ of trajectories. Obviously, the number of trajectories grows exponentially, and in order to avoid combinatorial explosion, quantitative constraints should be introduced (this could be visualized as placing the trajectories inside some kind of a ‘pipe’).
#  denotes an th possible predicted trajectory; , its value at an th position; , the maximum number of trajectories.  denotes a set of all trajectories that end at a position ; , a set of their values at an th position. Quite naturally, . It should be noted that that since a trajectory may not contain all successive points, generally a set  does not coincide with a set .
# In the case of , some techniques to build up sets of possible predicted trajectories and then determine a unified predicted value are possible:
#
#     1. Randomly perturbed trajectories. This technique employs a conventional iterative strategy (predicted values are calculated step by step at all intermediate positions). A unified predicted value is calculated for each trajectory independently, with the employment of its own sets of possible predicted values. This value is equal to a perturbed average value over elements of the largest cluster (cf. the technique № 8 of the previous list):
# , where  is a normally distributed random variable with zero mean and variance . In general, this technique closely resembles the respective technique for , but it requires that the possible predicted trajectory be built times. Figure 3 shows a number of possible predicted trajectories for the Lorenz series [tp] (a trajectory, perturbed).
#     2. Trajectories that rely on a choice of several clusters (the garden of forking trajectories; a fan of trajectories). We cluster the sets of possible predicted values at each intermediate position and considers the following centres of the clusters similarly to the second technique of the previous list:
# ,  . In this case, however, we choose several centres, thus making trajectories to branch. Usually, the first centre is that of the largest cluster with the rest being centres of the second largest cluster, the third, etc. and/or being centres of randomly chosen clusters. If all clusters are chosen randomly, we choose among clusters larger than a certain predefined threshold. Regardless of the way the centres are chosen, each one becomes the next element of a separate trajectory. In order to cut the number of the trajectories employed, we introduce constraints based on their weights. A weight of a trajectory is defined as a product of weights of its elements, which may be calculated by any of the three ways discussed above. In other words, a ‘fan’ of trajectories is transformed into a ‘pipe.’ For the cutting procedure, the current length (the number of elements) of trajectories should exceed a certain predefined threshold. As above, one may exclude trajectories with weights less than a certain value  or  percent of ‘lightest’ trajectories, regardless of their actual weights [tp] (a trajectory, multiple clustering).
#     3. Trajectories that rely on reduced initial information. The technique combines, in a sense, iterated and direct strategies (Ben Taieb et al., 2012). It builds principal trajectory, starting at point  as well a series of additional trajectories starting at points , ,…,, where  is a parameter. For an additional trajectory, observed values after its starting point are neglected and replaced by predicted values, calculated by the prediction algorithm in a usual way [tr] (a trajectory, reduced information).
# For all techniques, a unified predicted value is calculated as an average over the last values of the above trajectories: . It is worth noting that the second technique appears to be the most efficient, at the sacrifice, quite naturally, of computational efficiency.
# Interestingly, for the predictive-clustering algorithms discussed in this study, a set of non-predictable points appears to closely approximate a set of points for which the same algorithm without a procedure that identifies non-predictable points fails to make at least a satisfactory prediction. This observation provides the basis for a strategy to design various non-predictable-points identifying techniques.
#
# 2.5. Quality measures of unpredictable points identification algorithms
# The prediction method under discussion utilizes various techniques for identifying unpredictable points. They can either use sets of possible predicted values for a position to be predicted  () or a set of possible predicted trajectories that end at this point  (). For each prediction horizon  we may consider a set
# ; then its set of non-predictable intermediate position is defined as
# . A set of all non-predictable points of a test set is defined as
# . This set consists of all positions of a test set such that the prediction algorithm fails to predict, when it predicts  steps ahead. It is important to note that a point may belong to the set of non-predictable points if:
#     1. Its set of possible predicted values is empty;
#     2. This set comprises predicted values such that an adequate prediction value is impossible to obtain based on them.
# The functional (3) in effect minimizes the size of this set.
# Sets like this depend heavily on the algorithm used for a one-step-ahead prediction, , a value of , and a technique used to identify non-predictable points . To design baselines for non-predictable-points identifying algorithms – and to compare them (for a given) – we consider two extreme cases. For the first one, we do not employ a non-predictable-points identifying algorithm altogether: ,  by default. It means the prediction algorithm uses the closest motif regardless of how remote it is [fp] (forced prediction). A kind of light version of this baseline does not use motifs that are farther than a certain threshold [ab]. This version (the first extreme case) serves as a baseline for other.
# For the second extreme case, we assume that the prediction algorithm possesses a priori information about observed values at intermediate positions. More precisely, if the difference between its unified predicted value and the true value at the same position is more than  (a small parameter then the algorithm marks this point as unpredictable. Note that the algorithm does not replace its predictions by the true values – instead, it simply does not take clearly erroneous predictions into account during next prediction operations. Such points comprise, for a given prediction algorithm, its set of the ground-truth non-predictable points. Namely, for each point  that we are trying to predict, we can build up the set
# , where  is, as usual, a unified predicted value calculated for the set of possible predicted values . Hereinafter, the distance is Euclidean. Then, similarly to the above, its set of the ground-truth non-predictable intermediate points is defined as
#
# and the set of the ground-truth non-predictable points for a test set, as .
# Attempting to predict at  and excluding all intermediate points that fall into the set , leads to the second extreme case – a prediction method that uses an algorithm identifying unpredictable points using a priori information (in our internal team slang, this algorithm is named ‘the daemon’ – Socrates is known to have had his own daemon, who gave him advice in his most painful situations Wide-raging simulation reveals that the results of such an algorithm are nearly independent of a threshold value . Quite naturally, there is no such things for real-world algorithms: they do not possess information about the true values for intermediate positions , and those pieces of information they have at their disposal are either sets of possible predicted values  or sets of possible predicted trajectories . Nonetheless, this algorithm is extremely useful in determining the lower error boundary reachable by any other prediction algorithm. Algorithms identifying unpredictable points should be developed in a way that would make their results as close as possible to this boundary. Graphs in Fig. 4 exemplify dependences of the number of non-predictable points (Fig. 4 а) and the average error on predictable points (Fig. 4 b) on the prediction horizon  for the two extreme cases. The blue curves correspond to the first extreme case (intermediate non-predictable points are not identified at all), and orange, to the second (intermediate non-predictable points are identified with a priori information). It can be seen that in the first case the number of unpredictable points is equal to zero and the prediction error grows exponentially with . The second extreme algorithm demonstrates the opposite: the number of non-predictable points grows exponentially with , while the prediction error function remains mostly constant, bounded, and rather small. It is obvious that the first algorithm minimizes the functional (3), neglecting the functional (4); the second one minimizes the functional (4), neglecting the functional (3). Figures 5a and 5b display the true values (blue solid) and intermediate predicted values (red dashed) for the Lorenz series for the first (5 a) and second (5 b) extreme cases. From the latter subfigure we notice that the second algorithm does not make a prediction for all points, while making rather accurate predictions where it ‘decides’ to predict. On the other hand, we notice that in the first case the predicted trajectory diverges from the true one just after the point (a green disk in Fig. 5 a) that is identified as non-predictable by the second algorithm – the first algorithm must predict at this point (as with any point), and this immediately ruins the MSA prediction process, causing the predicted trajectory to diverge from the true one.
# Any other prediction algorithm is a trade-off between these two extreme algorithms. In the context of multi-step ahead prediction, the second case is essentially more interesting, since it allows one to predict a fairly large number of steps ahead. Consequently, all algorithms discussed below attempt to follow suit with this very algorithm (in the team’s internal slang, we referred to them as ‘approximating the daemon’ :).)
# Figure 5 c displays the true Lorenz series (blue), predicted values by Prof. Kurogi and colleagues (green), and the values predicted by the algorithm discussed in the present paper (red dashed line with disks). We should stress that at  the trajectory predicted by Prof. Kurogi and colleagues diverges from the true trajectory, while our algorithm identifies several non-predictable points. This makes it possible to predict essentially farther and find ‘hillocks’ of predictable points farther down from the last known point.
# Common sense (and large-scale simulation) suggests that such an algorithm will work efficiently if and only if a set of identified non-predictable points  is sufficiently close to the set of the ground-truth non-predictable points . Symmetric difference of the two sets constitutes an auxiliary quality measure for a technique identifying non-predictable points:
#
#
# (7)
#
# Two opposite situations can be observed:
#     1. The difference  is large, whereas the difference  is small;
#     2. The difference  is large, whereas the difference  is small.
# The first case seems to correlate with an overly optimistic algorithm while the second correlates with an overly conservative one.
#
# 2.6. Algorithms to identify non-predictable points (function  (1))
# These algorithms show a basic dichotomy between those that employ a set of possible predicted values  () and those that employ a set of possible predicted trajectories  (). In order to gain a better insight into the identification algorithms, we should consider a ‘paragon’ of a predictable point. We believe that its set of possible predicted values should consist of a single compact cluster, which includes an overwhelming majority of elements, and a number of small clusters and/or individual elements. On the contrary, non-predictable points are associated either with a continuum of possible predictable values not amenable to clustering or, vice versa, with several approximately equinumerous compact clusters. In terms of probability distributions, a predictable point correlates with a unimodal symmetric distribution with relatively small variance, while the unpredictable one correlates either with a nearly uniform distribution or with a distribution with several pronounced modes.
# In order to characterize unpredictable points, we employ the following quantities:
#     • Multimodality – a percent of possible predicted values remote from the main mode;
#     • Difference between  and  percentiles;
#     • Second, third, and fourth central moments, as well as the kurtosis of the distribution and its entropy.
#  We performed large-scale simulation on the validation set  by calculating sets of unpredictable points  and the ground-truth unpredictable points  for each feature separately. A comparison of these sets makes it possible to estimate the best threshold values for each feature. It also reveals that each feature (except entropy) by itself does not lead to larger values of objective (7) [en] (entropy).
# In terms of clustering of a set of possible predicted values, we employ the following quantities:
#     • Number of clusters;
#     • Percent of possible predicted values that fall into the largest cluster;
#     • Difference between the percentage of values belonging to the largest and smallest clusters.
# Similarly to the previous case, it is revealed that these quantities do not ‘work’ separately either. Consequently, the main course would be to use them together with quantities based on the distribution of possible predicted values.
# We employ the following methods to separate the features mentioned above into regions corresponding to predictable and unpredictable points:
#     1. Logistic regression [lr];
#     2. Support vector machine [sv];
#     3. Decision tree c 4.5 [dt];
#     4. K-nearest neighbours clustering [kn];
#     5. Multilayer perceptron with a single layer and 8 neurons in it [mp].
# ...
# Tables of the second type present information on the sets of non-predictable points for various variants of the method considered. The first columns are the same as the respective columns of the tables of the first type. Other columns indicate, (, 10, 50 and 100) , and F-measure
#  for the same prediction horizons.
# The Lorenz system (Atlee Jackson, 1985; Malinetskii & Potapov, 2000) with standard ‘chaotic’ parameters
# , integrated using the Runge-Kutta fourth-order method (an integration step is equal to ), yields a time series hereinafter referred to as the Lorenz series. The series in question is a typical chaotic series; it is used as a conventional benchmark to test forecasting procedures for chaotic time series.
# To distinguish chaotic and noisy time series, Rosso et al. (Rosso et al., 2007) proposed checking the position of a pair of quantities – entropy and complexity – on the appropriate plane. They calculated these quantities for the Lorenz series and got 0.68 and 0.45, thus making it possible to classify this series as chaotic. On the other hand, the highest Lyapunov exponent  for this series, calculated using the Eckman algorithm (Eckmann et al., 1986), is equal to 0.92, which is in a good agreement with results by Malinetskii and Potapov (Malinetskii & Potapov, 2000) (see p. 217). A strictly positive value of this quantity also speaks in favour of the series inherently chaotic nature.
# Numerical error for the fourth-order Runge-Kutta method amounts to
# . If the maximum prediction error is chosen as , then estimating a horizon of predictability would yield , or (in integration steps) 75 time series observations.
# For the Lorenz series, the first 3000 observations are discarded in order to ensure that trajectory moves in the neighbourhood of the respective strange attractor. The test set for the series consists of 1000 observations; the training set consists of 10000. Table I and II are the first and second type tables for the Lorenz series.
# Large-scale simulation reveals that for the first extreme case (a point is recognized as non-predictable only if there are no motifs close enough to make prediction, ) both the number of non-predictable points and average errors for predictable ones grow exponentially with a prediction horizon. Figure 7 demonstrates the number of non-predictable points (7a), RMSE (7b), and MAPE (7c) as a function of a prediction horizon in order to compare results obtained for the methods utilizing 100% and 4% of patterns. The green and red curves correspond to the method that employ the Wishart clustering (100% and 4%, respectively); orange and magenta correspond to those that do not employ any clustering algorithms (100% and 4%, respectively). Such results allow us to conclude that the prediction quality increases with the number of used patterns: the percent of non-predictable points is nearly zero for a larger prediction horizon, whereas the error measures for predictable points are comparable.
# Figure 8 presents the results for multi-step ahead prediction (the number of non-predictable points (8a), RMSE (8b), and MAPE (8c)); all methods does not identify non-predictable points altogether (4% of patterns is used). A unified predicted value is determined as an average (blue lines) [av] or a weighted average with weights inversely proportional to a distance to a cluster centre [wd], weights proportional to predictive length [wl], and combined weights [w] (green, orange, and cyan lines, respectively). For comparison, red lines represent the second extreme case (non-predictable points are identified with the employment of a priori information).  It may be concluded that the way the algorithm calculates a unified prediction value has little effect on the rate of this growth. Consequently, of crucial importance is the algorithm used to identify non-predictable points. In what follows, we discuss results for various identification techniques.
# The first identification technique employs entropy of possible predicted values distribution. Simulation reveals that the optimal threshold between the entropies of predictable and non-predictable points is equal to . Figure А1 (refer to Appendix A) portrays a typical empirical distribution for entropy for the ground-truth non-predictable points  and its complement to a testing set . It is quite obvious that entropy values correlating with the ground-truth non-predictable points and those correlating with predictable ones differ significantly. Unfortunately, it appears that it is impossible to design an efficient test based solely on entropy values.
# A number of identification techniques apply various machine learning algorithms to feature spaces build for sets of possible predicted values. Figure A9 summarizes the following results:
#     • Red curves correspond to the unpredictable points identified using a priori information;
#     • Blue points are not identified at all;
#     • The green ones are identified using a logistic regression classifier [lr];
#     • Orange ones – using an SVM classifier [sv];
#     • Cyan – decision tree [dt];
#     • Black – k-nearest neighbour [kn];
#     • Grey – multi-layer perceptron classifier[mp];
#     • Magenta – Adaboost ensemble of LogReg classifiers [al];
#     • Yellow – Adaboost ensemble of SVM classifiers [as];
#     • Pink – voting of LogReg classifiers [vl];
#     • Orange –stacking of LogReg classifiers [sl].
# A multi-layer perceptron contains 8 hidden layers and utilizes sigmoidal activation function; support vector machine employs polynomial kernel functions; C4.5 employs entropy criterion without any restriction on tree depth; k-nearest neighbour value is equal to 3.
#  	Among all considered machine learning methods, the ones based on logistic regression [lr] (green curves) and Adaboost ensemble of them [al] (magenta curves) stand out. They have a nearly constant dependence of both error measures on non-predictable points on the horizon, and their error measures for predictable points are comparable with those for the algorithm that used a priori information to identify non-predictable points (the second extreme case, red curves). Unfortunately, it also demonstrates an exponential growth of the number of non-predictable points with a rate larger than that of the second extreme case. The method that employs a multi-layer perceptron [mp] (gray curve), vice versa, demonstrates a moderate rate of growth of the number of non-predictable points with rapid error growth. Figures A2-A5 show predicted trajectories compared with a true one for these non-predictable-points identifying techniques. All methods that use an ensemble of classifiers to distinguish predictable and non-predictable points show comparable efficiency. Figure 10 displays results for the algorithms that use growth of the standard deviation value [rg] (green); of the number of DBSCAN clusters [sd] (orange); of the number of Wishart clusters [sw] (cyan) over three consecutive points to identify non-predictable points. Unfortunately, these approaches do not demonstrate desirable behavior. Figure A6 demonstrates true and predicted trajectories for this case.
#
# In order to implement an approach using branching trajectories (the ‘pipe’ concept), we cluster points using DBSCAN algorithm and then select those clusters that appear to be larger than = 5% of the total number of possible predicted values. Of these clusters, we chose two, using the following strategies:
#     1. Choosing the largest and the second largest clusters;
#     2. Choosing two randomly chosen clusters;
#     3. Choosing the largest and a number of randomly chosen clusters.
# The maximum allowed number of trajectories (pipe diameter) is equal to 20. It was ascertained that exponential error growth of the number of predictable points is peculiar to this technique, though it is not as steep as in the previous case.
# Simulation reveals that the methods based upon sets of predictable trajectories compare favourably to those based upon sets of predictable points. Figure 9 exhibits results for trajectories with random perturbation [tp]. The presented results correspond to a variance of the perturbation equal to 0.05. In order to identify non-predictable points, the algorithm clusters a set of final points of the predicted trajectories. If a size of the largest cluster is less than 4% of the total number of the final points, then the algorithm recognizes this point as non-predictable. To cluster points, we use DBSCAN with the following parameters: eps = 0.01, min_samples = 5. (Orange curve corresponds to the method that does not identify non-predictable points; it differs significantly from the respective curves of the previous plots (the red ones), since the algorithm builds up sets of possible predictable values in different manner). Figure A8 presents typical true and predicted trajectories for this case.
# An inspection of the figure indicates that the algorithm predicts values at positions up to , that significantly exceeds 75 – an estimated horizon of predictability for the Lorenz series (see above). This justifies the title of the present article. Figure A8 (refer to Appendix A) shows typical curves of error measures against the number of possible trajectories (100 % of patterns are used; no clustering technique is applied). The algorithm identifies non-predictable points when possible predicted trajectories diverge. Orange curves correspond to the algorithm that identifies non-predictable points with a priori information; blue, to the one that does not identify such points (). Results for the methods that use reduced initial information are presented in Fig. 10.
#
# The first column indicates a percentage of used patterns  and the way the algorithm obtains motifs (refer to the Section A training set). The second column indicates whether the algorithm builds up a set of possible predicted values or predicted trajectories and how it calculates a unified predicted value (refer to the Sections Sets of possible predicted values and A unified predicted value). The third column provides information on the way the algorithm identifies non-predictable points (refer to the Section Algorithms to identify non-predictable points. For information on symbolic labels used in these columns, please, refer to the previous section (in square brackets after the corresponding technique) or to the tables in Appendix B. The fourth column indicates the figure that displays results obtained using the respective variant of the algorithm and the colour used to plot the respective curves. Finally, all other columns present error measures for prediction horizons , 10, 50 and 100 (the number of non-predictable points, the mean absolute percentage error, and the root-mean-square error). Bold green colour indicates the best results after a horizon of predictability obtained with sets and trajectories of possible predicted values.
#
#
# 	Legends of the first 4 columns are the same as in Table I. Other columns indicate results for the prediction horizons of , 10, 50, 100, Recall, Precision, and  -measure.
#
# The second series considered is a real-world time series (hourly load values in Germany, from 23:00 12/31/2014 to 14:00 20/02/2016 https://www.entsoe.eu/data/power-stats/). A pairing of entropy and complexity for this series amounts to (0.499, 0.372), indicating chaoticity. Its highest Lyapunov exponent amounts to , which supports the hypothesis that the series is chaotic.
# All of the aforementioned methods were used in the analysis of this time series; results are demonstrated in tables 3 and 4, which are similar to tables 1 and 2 for the Lorenz series. We present essentially lesser number of plots for the sake of conciseness.
#
#
#
# Figure 11 demonstrates a section of the time series. Figure 12 demonstrates correlation between the number of non-predictable points and errors along with the corresponding prediction horizon for using trajectories of possible forecasted values [rd]. Figure 13 shows the same graphs when using a set of possible predicted values. Both graphs correspond to the best ways of calculating final predicted values and identifying unforecastable points amongst their respective classes. The best method is the pointwise using 100% of templates with perturbed trajectories (100p tp).
# We have recreated a simulation by Prof. Kurogi and his colleagues (2014) (multi-step ahead prediction of chaotic time series and out-of-bag estimate of the prediction performance for model selection). Figure 5c above displays the true Lorenz series (blue), predicted values by Prof. Kurogi and colleagues (green), and the values predicted by the algorithm discussed in the present paper (red dashed line with disks). The algorithm discussed appears to provide reliable predicted values at positions essentially farther (from the last observed value) than that by Prof. Kurogi and his colleagues, but it does not make predictions for all positions.
#
# VI. CONCLUSIONS
# Several conclusions may be reached:
#
# The paper discusses several novel strategies for multi-step prediction of chaotic time series. Generalized z-vectors, comprising non-successive observations, make it possible to obtain a fairly large set of possible predicted values for each point to be predicted. Upon examining such a set, it may be ascertained whether it is possible to produce a unified predicted value for it or not (whether the point is predictable or non-predictable), and determine this unified value if it is predictable. With non-predictable points, one may state the partial multi-step prediction problem as a two-objective problem: the first functional minimizes the number of non-predictable points, while the second minimizes the average error for predictable ones.
# It appears that for such algorithms the number of non-predictable points grows exponentially with a prediction horizon, but an average error for predictable points remains nearly constant and rather small. The strategies discussed allow a predictive-clustering algorithm to predict positions after a horizon of predictability for a benchmark (the Lorenz) and a real-world time series.
# It was concluded that the exact procedure of calculating the final forecasted value has little effect on the accuracy of forecasting, while an effective method of identifying non-predictable points dramatically expands the horizon of prediction. It is worth stressing that that this effect is possible only due to the fact that an algorithm examines sets of non-predictable points and determines whether it possible to calculate a unified prediction value for it (the second kind of non-predictable points).
# Large-scale simulation reveals that methods based upon sets of predictable trajectories compare favourably to those based upon sets of predictable points in terms of the ultimate prediction quality. This approach allowed for making some predictions after the horizon of predictability for the corresponding series.
# The strategies allow one to work with missing data in quite a natural way.
#
# VII. ACKNOWLEDGEMENTS
# The authors are deeply indebted to Mr. Joel Cumberland, HSE for the manuscript proof-reading and language editing. Authors are indebted to colleagues from Supercomputer Modelling Unit, HSE for access to the supercomputer and valuable advice.
# The article was prepared within the framework of the HSE University Basic Research Program.
#
# VIII. AUTHORS’ CONTRIBUTIONS.
#
# The contributors of this paper are as follows:
#     • Vasilii A. Gromov: conceptualization, methodology; project administration; supervision; writing - original draft;
#     • Philip S. Baranov: investigation, software, resources, formal analysis writing, review & editing;
#     • Alexandr Yu. Tsybakin: investigation, software, formal analysis.
